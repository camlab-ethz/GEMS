# %%
import os
import pickle
import pandas as pd
import numpy as np

def load_object(filename):
    with open(filename, 'rb') as f:
        return pickle.load(f)
# Out:
# /home/grabeda2/miniconda3/envs/similarity/lib/python3.10/site-packages/pandas/core/computation/expressions.py:21: UserWarning: Pandas requires version '2.8.0' or newer of 'numexpr' (version '2.7.3' currently installed).
#   from pandas.core.computation.check import NUMEXPR_INSTALLED

# %%
affinity_dict = load_object('/data/grbv/PDBbind/DTI5_general_affinity_dict.pkl')
len(affinity_dict)
# Out:
# 19443

# %%
casf2016_dir = '/data/grbv/PDBbind/DTI_5/input_graphs_esm2_t6_8M/test_data/casf2016'
casf2016_complexes = [filename[0:4] for filename in os.listdir(casf2016_dir) if 'graph' in filename]

casf2013_dir = '/data/grbv/PDBbind/DTI_5/input_graphs_esm2_t6_8M/test_data/casf2013'
casf2013_complexes = [filename[0:4] for filename in os.listdir(casf2013_dir) if 'graph' in filename]

train_dir = '/data/grbv/PDBbind/DTI_5/input_graphs_esm2_t6_8M/training_data'
train_complexes = [filename[0:4] for filename in os.listdir(train_dir) if 'graph' in filename]

# %%
# # Generate sequence dict with all complexes

# sequence_dict = {}
# save_path = '/data/grbv/PDBbind/DTI5_sequence_dict.pkl'


# data_dir = '/data/grbv/PDBbind/DTI5_input_data_processed'

# complexes = [folder for folder in os.listdir(data_dir) if len(folder)==4 and folder[0].isdigit()]
# for compl in complexes: 

#     in_dataset = False
#     if compl in train_complexes: in_dataset=True
#     elif compl in casf2013_complexes: in_dataset=True
#     elif compl in casf2016_complexes: in_dataset=True

#     if in_dataset:
#         path = os.path.join(data_dir, compl)

#         for file in os.scandir(path):
#             if file.name.endswith('protein_dict.pkl'):
#                 id = file.name[0:4]       
#                 protein_dict = load_object(file.path)

#                 seq = ''
#                 for chain in protein_dict:
#                     s = protein_dict[chain]['aa_seq']
#                     seq = seq + s

#                 sequence_dict[id]=seq   

# with open(save_path, 'wb') as fp:
#     pickle.dump(sequence_dict, fp)

# %%
sequence_dict = load_object('/data/grbv/PDBbind/DTI5_sequence_dict.pkl')
len(sequence_dict)
# Out:
# 19132

# %%
# # Save sequences as fasta file:

# fasta_file = '/data/grbv/PDBbind/DTI5_sequences.fasta'

# with open(fasta_file, 'w') as f:
#     for key in sequence_dict:
#         f.write('>' + key + '\n' + sequence_dict[key] + '\n')

# %%
#using mmseqs2 to cluster the sequences
import subprocess

#mmseqs easy-cluster test_data.fasta clusterRes tmp --min-seq-id 0.5 -c 0.8 --cov-mode 1

subprocess.run(['mmseqs', 'easy-cluster', '/data/grbv/PDBbind/DTI5_sequences.fasta', 'clusterRes', 'tmp', '--min-seq-id', '0.8', '-c', '0.8', '--cov-mode', '1'])
# Out:
# easy-cluster /data/grbv/PDBbind/DTI5_sequences.fasta clusterRes tmp --min-seq-id 0.8 -c 0.8 --cov-mode 1
#
# MMseqs Version:                     	15.6f452
# Substitution matrix                 	aa:blosum62.out,nucl:nucleotide.out
# Seed substitution matrix            	aa:VTML80.out,nucl:nucleotide.out
# Sensitivity                         	4
# k-mer length                        	0
# Target search mode                  	0
# k-score                             	seq:2147483647,prof:2147483647
# Alphabet size                       	aa:21,nucl:5
# Max sequence length                 	65535
# Max results per query               	20
# Split database                      	0
# Split mode                          	2
# Split memory limit                  	0
# Coverage threshold                  	0.8
# Coverage mode                       	1
# Compositional bias                  	1
# Compositional bias                  	1
# Diagonal scoring                    	true
# Exact k-mer matching                	0
# Mask residues                       	1
# Mask residues probability           	0.9
# Mask lower case residues            	0
# Minimum diagonal score              	15
# Selected taxa
# Include identical seq. id.          	false
# Spaced k-mers                       	1
# Preload mode                        	0
# Pseudo count a                      	substitution:1.100,context:1.400
# Pseudo count b                      	substitution:4.100,context:5.800
# Spaced k-mer pattern
# Local temporary path
# Threads                             	40
# Compressed                          	0
# Verbosity                           	3
# Add backtrace                       	false
# Alignment mode                      	3
# Alignment mode                      	0
# Allow wrapped scoring               	false
# E-value threshold                   	0.001
# Seq. id. threshold                  	0.8
# Min alignment length                	0
# Seq. id. mode                       	0
# Alternative alignments              	0
# Max reject                          	2147483647
# Max accept                          	2147483647
# Score bias                          	0
# Realign hits                        	false
# Realign score bias                  	-0.2
# Realign max seqs                    	2147483647
# Correlation score weight            	0
# Gap open cost                       	aa:11,nucl:5
# Gap extension cost                  	aa:1,nucl:2
# Zdrop                               	40
# Rescore mode                        	0
# Remove hits by seq. id. and coverage	false
# Sort results                        	0
# Cluster mode                        	0
# Max connected component depth       	1000
# Similarity type                     	2
# Weight file name
# Cluster Weight threshold            	0.9
# Single step clustering              	false
# Cascaded clustering steps           	3
# Cluster reassign                    	false
# Remove temporary files              	true
# Force restart with latest tmp       	false
# MPI runner
# k-mers per sequence                 	21
# Scale k-mers per sequence           	aa:0.000,nucl:0.200
# Adjust k-mer length                 	false
# Shift hash                          	67
# Include only extendable             	false
# Skip repeating k-mers               	false
# Database type                       	0
# Shuffle input database              	true
# Createdb mode                       	1
# Write lookup file                   	0
# Offset of numeric ids               	0
#
# createdb /data/grbv/PDBbind/DTI5_sequences.fasta tmp/1793533943949204301/input --dbtype 0 --shuffle 1 --createdb-mode 1 --write-lookup 0 --id-offset 0 --compressed 0 -v 3
#
# Shuffle database cannot be combined with --createdb-mode 0
# We recompute with --shuffle 0
# Converting sequences
# [=
# Time for merging to input_h: 0h 0m 0s 0ms
# Time for merging to input: 0h 0m 0s 0ms
# Database type: Aminoacid
# Time for processing: 0h 0m 0s 17ms
# Create directory tmp/1793533943949204301/clu_tmp
# cluster tmp/1793533943949204301/input tmp/1793533943949204301/clu tmp/1793533943949204301/clu_tmp --max-seqs 20 -c 0.8 --cov-mode 1 --spaced-kmer-mode 1 --alignment-mode 3 -e 0.001 --min-seq-id 0.8 --remove-tmp-files 1
#
# Set cluster sensitivity to -s 1.000000
# Set cluster mode GREEDY MEM
# Set cluster iterations to 1
# linclust tmp/1793533943949204301/input tmp/1793533943949204301/clu_tmp/846167229837907227/clu_redundancy tmp/1793533943949204301/clu_tmp/846167229837907227/linclust --cluster-mode 3 --max-iterations 1000 --similarity-type 2 --threads 40 --compressed 0 -v 3 --cluster-weight-threshold 0.9 --sub-mat 'aa:blosum62.out,nucl:nucleotide.out' -a 0 --alignment-mode 3 --alignment-output-mode 0 --wrapped-scoring 0 -e 0.001 --min-seq-id 0.8 --min-aln-len 0 --seq-id-mode 0 --alt-ali 0 -c 0.8 --cov-mode 1 --max-seq-len 65535 --comp-bias-corr 0 --comp-bias-corr-scale 1 --max-rejected 2147483647 --max-accept 2147483647 --add-self-matches 0 --db-load-mode 0 --pca substitution:1.100,context:1.400 --pcb substitution:4.100,context:5.800 --score-bias 0 --realign 0 --realign-score-bias -0.2 --realign-max-seqs 2147483647 --corr-score-weight 0 --gap-open aa:11,nucl:5 --gap-extend aa:1,nucl:2 --zdrop 40 --alph-size aa:13,nucl:5 --kmer-per-seq 21 --spaced-kmer-mode 1 --kmer-per-seq-scale aa:0.000,nucl:0.200 --adjust-kmer-len 0 --mask 0 --mask-prob 0.9 --mask-lower-case 0 -k 0 --hash-shift 67 --split-memory-limit 0 --include-only-extendable 0 --ignore-multi-kmer 0 --rescore-mode 0 --filter-hits 0 --sort-results 0 --remove-tmp-files 1 --force-reuse 0
#
# kmermatcher tmp/1793533943949204301/input tmp/1793533943949204301/clu_tmp/846167229837907227/linclust/10827341071345083566/pref --sub-mat 'aa:blosum62.out,nucl:nucleotide.out' --alph-size aa:13,nucl:5 --min-seq-id 0.8 --kmer-per-seq 21 --spaced-kmer-mode 1 --kmer-per-seq-scale aa:0.000,nucl:0.200 --adjust-kmer-len 0 --mask 0 --mask-prob 0.9 --mask-lower-case 0 --cov-mode 1 -k 0 -c 0.8 --max-seq-len 65535 --hash-shift 67 --split-memory-limit 0 --include-only-extendable 0 --ignore-multi-kmer 0 --threads 40 --compressed 0 -v 3 --cluster-weight-threshold 0.9
#
# kmermatcher tmp/1793533943949204301/input tmp/1793533943949204301/clu_tmp/846167229837907227/linclust/10827341071345083566/pref --sub-mat 'aa:blosum62.out,nucl:nucleotide.out' --alph-size aa:13,nucl:5 --min-seq-id 0.8 --kmer-per-seq 21 --spaced-kmer-mode 1 --kmer-per-seq-scale aa:0.000,nucl:0.200 --adjust-kmer-len 0 --mask 0 --mask-prob 0.9 --mask-lower-case 0 --cov-mode 1 -k 0 -c 0.8 --max-seq-len 65535 --hash-shift 67 --split-memory-limit 0 --include-only-extendable 0 --ignore-multi-kmer 0 --threads 40 --compressed 0 -v 3 --cluster-weight-threshold 0.9
#
# Database size: 19132 type: Aminoacid
# Reduced amino acid alphabet: (A S T) (C) (D B N) (E Q Z) (F Y) (G) (H) (I V) (K R) (L J M) (P) (W) (X)
#
# Generate k-mers list for 1 split
# [=================================================================] 19.13K 0s 65ms
# Sort kmer 0h 0m 0s 195ms
# Sort by rep. sequence 0h 0m 0s 168ms
# Time for fill: 0h 0m 0s 9ms
# Time for merging to pref: 0h 0m 0s 0ms
# Time for processing: 0h 0m 0s 595ms
# rescorediagonal tmp/1793533943949204301/input tmp/1793533943949204301/input tmp/1793533943949204301/clu_tmp/846167229837907227/linclust/10827341071345083566/pref tmp/1793533943949204301/clu_tmp/846167229837907227/linclust/10827341071345083566/pref_rescore1 --sub-mat 'aa:blosum62.out,nucl:nucleotide.out' --rescore-mode 0 --wrapped-scoring 0 --filter-hits 0 -e 0.001 -c 0.8 -a 0 --cov-mode 1 --min-seq-id 0.8 --min-aln-len 0 --seq-id-mode 0 --add-self-matches 0 --sort-results 0 --db-load-mode 0 --threads 40 --compressed 0 -v 3
#
# [===========================================================] 19.13K 0s 47ms
# ======Time for merging to pref_rescore1: 0h 0m 0s 9ms
# Time for processing: 0h 0m 0s 141ms
# clust tmp/1793533943949204301/input tmp/1793533943949204301/clu_tmp/846167229837907227/linclust/10827341071345083566/pref_rescore1 tmp/1793533943949204301/clu_tmp/846167229837907227/linclust/10827341071345083566/pre_clust --cluster-mode 3 --max-iterations 1000 --similarity-type 2 --threads 40 --compressed 0 -v 3 --cluster-weight-threshold 0.9
#
# Clustering mode: Greedy Low Mem
# Total time: 0h 0m 0s 127ms
#
# Size of the sequence database: 19132
# Size of the alignment database: 19132
# Number of clusters: 8270
#
# Writing results 0h 0m 0s 2ms
# Time for merging to pre_clust: 0h 0m 0s 0ms
# Time for processing: 0h 0m 0s 138ms
# createsubdb tmp/1793533943949204301/clu_tmp/846167229837907227/linclust/10827341071345083566/order_redundancy tmp/1793533943949204301/input tmp/1793533943949204301/clu_tmp/846167229837907227/linclust/10827341071345083566/input_step_redundancy -v 3 --subdb-mode 1
#
# Time for merging to input_step_redundancy: 0h 0m 0s 0ms
# Time for processing: 0h 0m 0s 3ms
# createsubdb tmp/1793533943949204301/clu_tmp/846167229837907227/linclust/10827341071345083566/order_redundancy tmp/1793533943949204301/clu_tmp/846167229837907227/linclust/10827341071345083566/pref tmp/1793533943949204301/clu_tmp/846167229837907227/linclust/10827341071345083566/pref_filter1 -v 3 --subdb-mode 1
#
# Time for merging to pref_filter1: 0h 0m 0s 0ms
# Time for processing: 0h 0m 0s 4ms
# filterdb tmp/1793533943949204301/clu_tmp/846167229837907227/linclust/10827341071345083566/pref_filter1 tmp/1793533943949204301/clu_tmp/846167229837907227/linclust/10827341071345083566/pref_filter2 --filter-file tmp/1793533943949204301/clu_tmp/846167229837907227/linclust/10827341071345083566/order_redundancy --threads 40 --compressed 0 -v 3
#
# Filtering using file(s)
# [=================================================================] 8.27K 0s 58ms
# Time for merging to pref_filter2: 0h 0m 0s 5ms
# Time for processing: 0h 0m 0s 109ms
# rescorediagonal tmp/1793533943949204301/clu_tmp/846167229837907227/linclust/10827341071345083566/input_step_redundancy tmp/1793533943949204301/clu_tmp/846167229837907227/linclust/10827341071345083566/input_step_redundancy tmp/1793533943949204301/clu_tmp/846167229837907227/linclust/10827341071345083566/pref_filter2 tmp/1793533943949204301/clu_tmp/846167229837907227/linclust/10827341071345083566/pref_rescore2 --sub-mat 'aa:blosum62.out,nucl:nucleotide.out' --rescore-mode 1 --wrapped-scoring 0 --filter-hits 1 -e 0.001 -c 0.8 -a 0 --cov-mode 1 --min-seq-id 0.8 --min-aln-len 0 --seq-id-mode 0 --add-self-matches 0 --sort-results 0 --db-load-mode 0 --threads 40 --compressed 0 -v 3
#
# [======================================================] 8.27K 0s 30ms
# ===========Time for merging to pref_rescore2: 0h 0m 0s 18ms
# Time for processing: 0h 0m 0s 121ms
# align tmp/1793533943949204301/clu_tmp/846167229837907227/linclust/10827341071345083566/input_step_redundancy tmp/1793533943949204301/clu_tmp/846167229837907227/linclust/10827341071345083566/input_step_redundancy tmp/1793533943949204301/clu_tmp/846167229837907227/linclust/10827341071345083566/pref_rescore2 tmp/1793533943949204301/clu_tmp/846167229837907227/linclust/10827341071345083566/aln --sub-mat 'aa:blosum62.out,nucl:nucleotide.out' -a 0 --alignment-mode 3 --alignment-output-mode 0 --wrapped-scoring 0 -e 0.001 --min-seq-id 0.8 --min-aln-len 0 --seq-id-mode 0 --alt-ali 0 -c 0.8 --cov-mode 1 --max-seq-len 65535 --comp-bias-corr 0 --comp-bias-corr-scale 1 --max-rejected 2147483647 --max-accept 2147483647 --add-self-matches 0 --db-load-mode 0 --pca substitution:1.100,context:1.400 --pcb substitution:4.100,context:5.800 --score-bias 0 --realign 0 --realign-score-bias -0.2 --realign-max-seqs 2147483647 --corr-score-weight 0 --gap-open aa:11,nucl:5 --gap-extend aa:1,nucl:2 --zdrop 40 --threads 40 --compressed 0 -v 3
#
# Compute score, coverage and sequence identity
# Query database size: 8270 type: Aminoacid
# Target database size: 8270 type: Aminoacid
# Calculation of alignments
# [=================================================================] 8.27K 1s 152ms
# Time for merging to aln: 0h 0m 0s 12ms
# 18032 alignments calculated
# 16095 sequence pairs passed the thresholds (0.892580 of overall calculated)
# 1.946191 hits per query sequence
# Time for processing: 0h 0m 1s 210ms
# clust tmp/1793533943949204301/clu_tmp/846167229837907227/linclust/10827341071345083566/input_step_redundancy tmp/1793533943949204301/clu_tmp/846167229837907227/linclust/10827341071345083566/aln tmp/1793533943949204301/clu_tmp/846167229837907227/linclust/10827341071345083566/clust --cluster-mode 3 --max-iterations 1000 --similarity-type 2 --threads 40 --compressed 0 -v 3 --cluster-weight-threshold 0.9
#
# Clustering mode: Greedy Low Mem
# Total time: 0h 0m 0s 101ms
#
# Size of the sequence database: 8270
# Size of the alignment database: 8270
# Number of clusters: 4260
#
# Writing results 0h 0m 0s 1ms
# Time for merging to clust: 0h 0m 0s 0ms
# Time for processing: 0h 0m 0s 108ms
# mergeclusters tmp/1793533943949204301/input tmp/1793533943949204301/clu_tmp/846167229837907227/clu_redundancy tmp/1793533943949204301/clu_tmp/846167229837907227/linclust/10827341071345083566/pre_clust tmp/1793533943949204301/clu_tmp/846167229837907227/linclust/10827341071345083566/clust --threads 40 --compressed 0 -v 3
#
# Clustering step 1
# [=================================================================] 8.27K 0s 48ms
# Clustering step 2
# [=================================================================] 4.26K 0s 125ms
# Write merged clustering
# [=================================================================] 19.13K 0s 189ms
# Time for merging to clu_redundancy: 0h 0m 0s 3ms
# Time for processing: 0h 0m 0s 239ms
# rmdb tmp/1793533943949204301/clu_tmp/846167229837907227/linclust/10827341071345083566/pref_filter1 -v 3
#
# Time for processing: 0h 0m 0s 0ms
# rmdb tmp/1793533943949204301/clu_tmp/846167229837907227/linclust/10827341071345083566/pref -v 3
#
# Time for processing: 0h 0m 0s 0ms
# rmdb tmp/1793533943949204301/clu_tmp/846167229837907227/linclust/10827341071345083566/pref_rescore1 -v 3
#
# Time for processing: 0h 0m 0s 1ms
# rmdb tmp/1793533943949204301/clu_tmp/846167229837907227/linclust/10827341071345083566/pre_clust -v 3
#
# Time for processing: 0h 0m 0s 0ms
# rmdb tmp/1793533943949204301/clu_tmp/846167229837907227/linclust/10827341071345083566/input_step_redundancy -v 3
#
# Time for processing: 0h 0m 0s 0ms
# rmdb tmp/1793533943949204301/clu_tmp/846167229837907227/linclust/10827341071345083566/input_step_redundancy_h -v 3
#
# Time for processing: 0h 0m 0s 0ms
# rmdb tmp/1793533943949204301/clu_tmp/846167229837907227/linclust/10827341071345083566/pref_filter2 -v 3
#
# Time for processing: 0h 0m 0s 1ms
# rmdb tmp/1793533943949204301/clu_tmp/846167229837907227/linclust/10827341071345083566/pref_rescore2 -v 3
#
# Time for processing: 0h 0m 0s 2ms
# rmdb tmp/1793533943949204301/clu_tmp/846167229837907227/linclust/10827341071345083566/aln -v 3
#
# Time for processing: 0h 0m 0s 2ms
# rmdb tmp/1793533943949204301/clu_tmp/846167229837907227/linclust/10827341071345083566/clust -v 3
#
# Time for processing: 0h 0m 0s 0ms
# createsubdb tmp/1793533943949204301/clu_tmp/846167229837907227/clu_redundancy tmp/1793533943949204301/input tmp/1793533943949204301/clu_tmp/846167229837907227/input_step_redundancy -v 3 --subdb-mode 1
#
# Time for merging to input_step_redundancy: 0h 0m 0s 0ms
# Time for processing: 0h 0m 0s 7ms
# prefilter tmp/1793533943949204301/clu_tmp/846167229837907227/input_step_redundancy tmp/1793533943949204301/clu_tmp/846167229837907227/input_step_redundancy tmp/1793533943949204301/clu_tmp/846167229837907227/pref_step0 --sub-mat 'aa:blosum62.out,nucl:nucleotide.out' --seed-sub-mat 'aa:VTML80.out,nucl:nucleotide.out' -s 1 -k 0 --target-search-mode 0 --k-score seq:2147483647,prof:2147483647 --alph-size aa:21,nucl:5 --max-seq-len 65535 --max-seqs 20 --split 0 --split-mode 2 --split-memory-limit 0 -c 0.8 --cov-mode 1 --comp-bias-corr 0 --comp-bias-corr-scale 1 --diag-score 0 --exact-kmer-matching 0 --mask 1 --mask-prob 0.9 --mask-lower-case 0 --min-ungapped-score 0 --add-self-matches 0 --spaced-kmer-mode 1 --db-load-mode 0 --pca substitution:1.100,context:1.400 --pcb substitution:4.100,context:5.800 --threads 40 --compressed 0 -v 3
#
# Query database size: 4260 type: Aminoacid
# Estimated memory consumption: 1003M
# Target database size: 4260 type: Aminoacid
# Index table k-mer threshold: 154 at k-mer size 6
# Index table: counting k-mers
# [=================================================================] 4.26K 0s 162ms
# Index table: Masked residues: 11745
# Index table: fill
# [=================================================================] 4.26K 0s 46ms
# Index statistics
# Entries:          698446
# DB size:          492 MB
# Avg k-mer size:   0.010913
# Top 10 k-mers
#     LGLKFP	120
#     VHFAQS	114
#     WNGLGV	109
#     SVCLFY	99
#     DYPPVS	60
#     KGSFAP	59
#     ASKPFP	59
#     TYCVKP	59
#     TCVHSS	59
#     YFEVSW	59
# Time for index table init: 0h 0m 1s 61ms
# Process prefiltering step 1 of 1
#
# k-mer similarity threshold: 154
# Starting prefiltering scores calculation (step 1 of 1)
# Query db start 1 to 4260
# Target db start 1 to 4260
# [=================================================================] 4.26K 0s 87ms
#
# 2.274136 k-mers per position
# 1123 DB matches per sequence
# 0 overflows
# 5 sequences passed prefiltering per query sequence
# 2 median result list length
# 0 sequences with 0 size result lists
# Time for merging to pref_step0: 0h 0m 0s 4ms
# Time for processing: 0h 0m 1s 617ms
# align tmp/1793533943949204301/clu_tmp/846167229837907227/input_step_redundancy tmp/1793533943949204301/clu_tmp/846167229837907227/input_step_redundancy tmp/1793533943949204301/clu_tmp/846167229837907227/pref_step0 tmp/1793533943949204301/clu_tmp/846167229837907227/aln_step0 --sub-mat 'aa:blosum62.out,nucl:nucleotide.out' -a 0 --alignment-mode 3 --alignment-output-mode 0 --wrapped-scoring 0 -e 0.001 --min-seq-id 0.8 --min-aln-len 0 --seq-id-mode 0 --alt-ali 0 -c 0.8 --cov-mode 1 --max-seq-len 65535 --comp-bias-corr 0 --comp-bias-corr-scale 1 --max-rejected 2147483647 --max-accept 2147483647 --add-self-matches 0 --db-load-mode 0 --pca substitution:1.100,context:1.400 --pcb substitution:4.100,context:5.800 --score-bias 0 --realign 0 --realign-score-bias -0.2 --realign-max-seqs 2147483647 --corr-score-weight 0 --gap-open aa:11,nucl:5 --gap-extend aa:1,nucl:2 --zdrop 40 --threads 40 --compressed 0 -v 3
#
# Compute score, coverage and sequence identity
# Query database size: 4260 type: Aminoacid
# Target database size: 4260 type: Aminoacid
# Calculation of alignments
# [=================================================================] 4.26K 1s 608ms
# Time for merging to aln_step0: 0h 0m 0s 4ms
# 19082 alignments calculated
# 9015 sequence pairs passed the thresholds (0.472435 of overall calculated)
# 2.116197 hits per query sequence
# Time for processing: 0h 0m 1s 673ms
# clust tmp/1793533943949204301/clu_tmp/846167229837907227/input_step_redundancy tmp/1793533943949204301/clu_tmp/846167229837907227/aln_step0 tmp/1793533943949204301/clu_tmp/846167229837907227/clu_step0 --cluster-mode 3 --max-iterations 1000 --similarity-type 2 --threads 40 --compressed 0 -v 3 --cluster-weight-threshold 0.9
#
# Clustering mode: Greedy Low Mem
# Total time: 0h 0m 0s 104ms
#
# Size of the sequence database: 4260
# Size of the alignment database: 4260
# Number of clusters: 3464
#
# Writing results 0h 0m 0s 0ms
# Time for merging to clu_step0: 0h 0m 0s 0ms
# Time for processing: 0h 0m 0s 111ms
# mergeclusters tmp/1793533943949204301/input tmp/1793533943949204301/clu tmp/1793533943949204301/clu_tmp/846167229837907227/clu_redundancy tmp/1793533943949204301/clu_tmp/846167229837907227/clu_step0 --threads 40 --compressed 0 -v 3
#
# Clustering step 1
# [=================================================================] 4.26K 0s 45ms
# Clustering step 2
# [=================================================================] 3.46K 0s 112ms
# Write merged clustering
# [=================================================================] 19.13K 0s 165ms
# Time for merging to clu: 0h 0m 0s 10ms
# Time for processing: 0h 0m 0s 202ms
# rmdb tmp/1793533943949204301/clu_tmp/846167229837907227/clu_redundancy -v 3
#
# Time for processing: 0h 0m 0s 0ms
# rmdb tmp/1793533943949204301/clu_tmp/846167229837907227/input_step_redundancy -v 3
#
# Time for processing: 0h 0m 0s 0ms
# rmdb tmp/1793533943949204301/clu_tmp/846167229837907227/input_step_redundancy_h -v 3
#
# Time for processing: 0h 0m 0s 0ms
# rmdb tmp/1793533943949204301/clu_tmp/846167229837907227/pref_step0 -v 3
#
# Time for processing: 0h 0m 0s 1ms
# rmdb tmp/1793533943949204301/clu_tmp/846167229837907227/aln_step0 -v 3
#
# Time for processing: 0h 0m 0s 2ms
# rmdb tmp/1793533943949204301/clu_tmp/846167229837907227/clu_step0 -v 3
#
# Time for processing: 0h 0m 0s 0ms
# createtsv tmp/1793533943949204301/input tmp/1793533943949204301/input tmp/1793533943949204301/clu tmp/1793533943949204301/cluster.tsv --threads 40 -v 3
#
# Time for merging to cluster.tsv: 0h 0m 0s 17ms
# Time for processing: 0h 0m 0s 86ms
# result2repseq tmp/1793533943949204301/input tmp/1793533943949204301/clu tmp/1793533943949204301/clu_rep --db-load-mode 0 --compressed 0 --threads 40 -v 3
#
# [=================================================================] 3.46K 0s 37ms
# Time for merging to clu_rep: 0h 0m 0s 16ms
# Time for processing: 0h 0m 0s 80ms
# result2flat tmp/1793533943949204301/input tmp/1793533943949204301/input tmp/1793533943949204301/clu_rep tmp/1793533943949204301/rep_seq.fasta --use-fasta-header -v 3
#
# Time for processing: 0h 0m 0s 16ms
# createseqfiledb tmp/1793533943949204301/input tmp/1793533943949204301/clu tmp/1793533943949204301/clu_seqs --threads 40 -v 3
#
# [=================================================================] 3.46K 0s 64ms
# Time for merging to clu_seqs: 0h 0m 0s 4ms
# Time for processing: 0h 0m 0s 113ms
# result2flat tmp/1793533943949204301/input tmp/1793533943949204301/input tmp/1793533943949204301/clu_seqs tmp/1793533943949204301/all_seqs.fasta -v 3
#
# Time for processing: 0h 0m 0s 52ms
# rmdb tmp/1793533943949204301/input -v 3
#
# Time for processing: 0h 0m 0s 0ms
# rmdb tmp/1793533943949204301/input_h -v 3
#
# Time for processing: 0h 0m 0s 0ms
# rmdb tmp/1793533943949204301/clu_seqs -v 3
#
# Time for processing: 0h 0m 0s 6ms
# rmdb tmp/1793533943949204301/clu_rep -v 3
#
# Time for processing: 0h 0m 0s 1ms
# rmdb tmp/1793533943949204301/clu -v 3
#
# Time for processing: 0h 0m 0s 1ms
# CompletedProcess(args=['mmseqs', 'easy-cluster', '/data/grbv/PDBbind/DTI5_sequences.fasta', 'clusterRes', 'tmp', '--min-seq-id', '0.8', '-c', '0.8', '--cov-mode', '1'], returncode=0)

# %%
#lets analyse the clusterRes file
clusterRes = pd.read_csv('clusterRes_cluster.tsv', sep='\t', header=None)
clusterRes.head()
# Out:
#       0     1
# 0  1bcj  1bcj
# 1  2brp  2brp
# 2  2brp  1f9g
# 3  5gmh  5gmh
# 4  3tww  3tww

# %%
'''All members of the clustering are listed line by line. 
Each cluster is a consecutive block in the file. The first column always contains the representative sequence, the second contains the cluster member. For the example the cluster with the representative sequence Q0KJ32 contains four members itself and C0W539, D6KVP9, D1Y890.
 IDs are parsed from the header from the input database (see id parsing from headers).
'''
#lets count the number of clusters and its memebers
print(len(clusterRes[0].unique()), 'number of clusters')
# Out:
# 3464 number of clusters

# %%
#lets count the number of sequences in each cluster
clusterRes[0].value_counts()
# Out:
# 0
# 5kr2    438
# 5doh    420
# 3kmx    342
# 2v22    223
# 2tpi    194
#        ...
# 1mfa      1
# 6bvb      1
# 4np9      1
# 4ris      1
# 5xhz      1
# Name: count, Length: 3464, dtype: int64

# %%
import csv

with open('clusterRes_cluster.tsv', 'r', newline='') as infile, open('clusterRes_cluster_DTI5_1.tsv', 'w', newline='') as outfile:
    reader = csv.reader(infile, delimiter='\t')
    writer = csv.writer(outfile, delimiter='\t')

    for row in reader:

        # Retrieve the value from the dictionary based on the second column
        id = row[1]

        if id in train_complexes: string = 'training'
        if id in casf2016_complexes: string = 'test    '
        if id in casf2013_complexes: string = 'test    '

        affinity = affinity_dict[id]['log_kd_ki']

        # Add this value as a third column
        row.append(string)
        row.append(affinity)

        
        # Write the modified row to the output file
        writer.writerow(row)

# %%
import networkx as nx
import matplotlib.pyplot as plt

# Create a graph
G = nx.Graph()

# Add edges from the DataFrame
for index, row in clusterRes.iterrows():
    G.add_edge(row[0], row[1])

# Set node positions using the spring layout
pos = nx.spring_layout(G)
# Set a clear background
plt.figure(figsize=(50, 50))
plt.gca().set_facecolor('white')

# Draw nodes with adjusted size and color
nx.draw_networkx_nodes(G, pos, node_size=200, node_color='skyblue', alpha=0.8)

# Draw edges with adjusted thickness and color
nx.draw_networkx_edges(G, pos, width=1.0, alpha=0.5, edge_color='gray')

# Draw labels with adjusted font size
nx.draw_networkx_labels(G, pos, font_size=8, font_color='black')


# Show the plot
plt.axis('off')  # Turn off axis
plt.show()
