# %%
import os
import pickle
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ### General Set

# %%
index_file = '/data/grbv/PDBbind/index/INDEX_general_PL_data.2020'

# %%
results_general = {}

successful = 0
failed = 0
Kd_complexes = 0
Ki_complexes = 0
IC50_complexes = 0

# Open the text file for reading
with open(index_file, 'r') as file:
    # Skip the header lines
    for _ in range(6):
        next(file)

    # Read and process each line in the file
    for line in file:

        # Split the line into columns based on whitespace
        columns = line.strip().split()

        # Extract relevant information from columns
        pdb_code = columns[0]
        resolution = columns[1]
        kd_or_ki_value_str = columns[4]

        if '<=' in kd_or_ki_value_str:
            type, affinity = kd_or_ki_value_str.strip().split('<=')
            value = affinity[:-2]
            unit = affinity[-2:]

        elif '>=' in kd_or_ki_value_str:
            type, affinity = kd_or_ki_value_str.strip().split('>=')
            value = affinity[:-2]
            unit = affinity[-2:]

        elif '=' in kd_or_ki_value_str:
            type, affinity = kd_or_ki_value_str.strip().split('=')
            value = affinity[:-2]
            unit = affinity[-2:]

        elif '>' in kd_or_ki_value_str:
            type, affinity = kd_or_ki_value_str.strip().split('>')
            value = affinity[:-2]
            unit = affinity[-2:]

        elif '<' in kd_or_ki_value_str:
            type, affinity = kd_or_ki_value_str.strip().split('<')
            value = affinity[:-2]
            unit = affinity[-2:]

        elif '~' in kd_or_ki_value_str:
            type, affinity = kd_or_ki_value_str.strip().split('~')
            value = affinity[:-2]
            unit = affinity[-2:]

        else:
            raise Exception
            

        # Convert the numeric part to a float
        value = float(value)

        # Apply scaling factor based on the unit

        if unit == 'M':
            affinity = value
            results_general[pdb_code]={type:affinity, 'resolution':resolution}      
        elif unit == 'mM':
            affinity = value * 1e-3
            results_general[pdb_code]={type:affinity, 'resolution':resolution}
        elif unit == 'uM':
            affinity = value * 1e-6
            results_general[pdb_code]={type:affinity, 'resolution':resolution}
        elif unit == 'nM':
            affinity = value * 1e-9
            results_general[pdb_code]={type:affinity, 'resolution':resolution}
        elif unit == 'pM':
            affinity = value * 1e-12
            results_general[pdb_code]={type:affinity, 'resolution':resolution}
        elif unit == 'fM':
            affinity = value * 1e-15
            results_general[pdb_code]={type:affinity, 'resolution':resolution}
        else:
            print(pdb_code)
            raise Exception


        successful+=1
        if type == 'Kd': Kd_complexes+=1
        elif type == 'Ki': Ki_complexes+=1
        elif type == 'IC50': IC50_complexes+=1
        else: print(pdb_code, type, unit)

        

print(f'Extracted Affinity Value from {successful} Complexes')
print(f'Number of Datapoints with Kd = {Kd_complexes}')
print(f'Number of Datapoints with Ki = {Ki_complexes}')
print(f'Number of Datapoints with IC50 = {IC50_complexes}')
# Out:
# Extracted Affinity Value from 19443 Complexes
# Number of Datapoints with Kd = 7249
# Number of Datapoints with Ki = 5004
# Number of Datapoints with IC50 = 7190

# %%
# Print the results
for pdb_code, value in results_general.items():
    print(f'PDB code: {pdb_code}, Affinity Data {value}')
# Out:
# PDB code: 3zzf, Affinity Data {'Ki': 0.4, 'resolution': '2.20'}
# PDB code: 3gww, Affinity Data {'IC50': 0.355, 'resolution': '2.46'}
# PDB code: 1w8l, Affinity Data {'Ki': 0.32, 'resolution': '1.80'}
# PDB code: 3fqa, Affinity Data {'IC50': 0.32, 'resolution': '2.35'}
# PDB code: 1zsb, Affinity Data {'Kd': 0.25, 'resolution': '2.00'}
# PDB code: 6h9v, Affinity Data {'Kd': 0.22, 'resolution': '1.52'}
# PDB code: 4obv, Affinity Data {'Ki': 0.178, 'resolution': '2.84'}
# PDB code: 1wkm, Affinity Data {'Ki': 0.15, 'resolution': '2.30'}
# PDB code: 3k41, Affinity Data {'Kd': 0.15, 'resolution': '1.90'}
# PDB code: 4eu3, Affinity Data {'Ki': 0.15, 'resolution': '1.58'}
# PDB code: 2w97, Affinity Data {'Kd': 0.11, 'resolution': '2.29'}
# PDB code: 1p0y, Affinity Data {'Ki': 0.1008, 'resolution': '2.55'}
# PDB code: 2b1r, Affinity Data {'Ki': 0.101, 'resolution': '2.20'}
# PDB code: 2d2v, Affinity Data {'Ki': 0.1, 'resolution': '2.50'}
# PDB code: 1aw1, Affinity Data {'Ki': 0.089, 'resolution': '2.70'}
# PDB code: 1maw, Affinity Data {'Kd': 0.08, 'resolution': '3.00'}
# PDB code: 3fl9, Affinity Data {'IC50': 0.0772, 'resolution': '2.40'}
# PDB code: 5eb2, Affinity Data {'Kd': 0.07690000000000001, 'resolution': '2.71'}
# PDB code: 4lh2, Affinity Data {'Ki': 0.058, 'resolution': '1.67'}
# PDB code: 4to8, Affinity Data {'IC50': 0.0569, 'resolution': '2.10'}
# PDB code: 4fci, Affinity Data {'Ki': 0.055, 'resolution': '1.82'}
# PDB code: 4fck, Affinity Data {'Ki': 0.055, 'resolution': '1.90'}
# PDB code: 4clp, Affinity Data {'Kd': 0.054200000000000005, 'resolution': '1.90'}
# PDB code: 1f9g, Affinity Data {'Ki': 0.053, 'resolution': '2.00'}
# PDB code: 1a0t, Affinity Data {'Kd': 0.05, 'resolution': '2.40'}
# PDB code: 1b74, Affinity Data {'Ki': 0.05, 'resolution': '2.30'}
# PDB code: 2fah, Affinity Data {'Ki': 0.05, 'resolution': '2.09'}
# PDB code: 5oxm, Affinity Data {'Kd': 0.05, 'resolution': '2.30'}
# PDB code: 2igw, Affinity Data {'Kd': 0.049, 'resolution': '1.78'}
# PDB code: 5mnc, Affinity Data {'Kd': 0.0485, 'resolution': '0.92'}
# PDB code: 5mny, Affinity Data {'Kd': 0.0485, 'resolution': '1.43'}
# PDB code: 5moo, Affinity Data {'Kd': 0.0485, 'resolution': '1.44'}
# PDB code: 2vl1, Affinity Data {'Ki': 0.045, 'resolution': '2.15'}
# PDB code: 3nm6, Affinity Data {'Kd': 0.045, 'resolution': '1.60'}
# PDB code: 1qpb, Affinity Data {'Kd': 0.044, 'resolution': '2.40'}
# PDB code: 6k2n, Affinity Data {'Kd': 0.0434, 'resolution': '1.80'}
# PDB code: 1hty, Affinity Data {'IC50': 0.04, 'resolution': '1.40'}
# PDB code: 1o4l, Affinity Data {'IC50': 0.04, 'resolution': '1.65'}
# PDB code: 1o4m, Affinity Data {'IC50': 0.04, 'resolution': '1.60'}
# PDB code: 1o4n, Affinity Data {'IC50': 0.04, 'resolution': '1.60'}
# PDB code: 2hdq, Affinity Data {'Ki': 0.04, 'resolution': '2.10'}
# PDB code: 3eor, Affinity Data {'Kd': 0.04, 'resolution': '2.90'}
# PDB code: 3e81, Affinity Data {'Ki': 0.037, 'resolution': '1.63'}
# PDB code: 1ozv, Affinity Data {'Ki': 0.0366, 'resolution': '2.65'}
# PDB code: 1utp, Affinity Data {'Kd': 0.036000000000000004, 'resolution': '1.30'}
# PDB code: 5eb3, Affinity Data {'Kd': 0.0352, 'resolution': '2.40'}
# PDB code: 1tnk, Affinity Data {'Ki': 0.0325, 'resolution': '1.80'}
# PDB code: 4bh4, Affinity Data {'Kd': 0.032, 'resolution': '1.90'}
# PDB code: 5vqe, Affinity Data {'Kd': 0.032, 'resolution': '1.89'}
# PDB code: 4lh3, Affinity Data {'Ki': 0.03, 'resolution': '1.81'}
# PDB code: 5ct1, Affinity Data {'Kd': 0.0302, 'resolution': '2.00'}
# PDB code: 5ele, Affinity Data {'Kd': 0.03, 'resolution': '1.60'}
# PDB code: 3mwe, Affinity Data {'Ki': 0.029, 'resolution': '2.20'}
# PDB code: 4amw, Affinity Data {'Ki': 0.028300000000000002, 'resolution': '1.90'}
# PDB code: 1iig, Affinity Data {'Ki': 0.027, 'resolution': '2.60'}
# PDB code: 3rup, Affinity Data {'Ki': 0.027, 'resolution': '1.99'}
# PDB code: 5cs5, Affinity Data {'Kd': 0.026600000000000002, 'resolution': '1.90'}
# PDB code: 5ofv, Affinity Data {'Kd': 0.0262, 'resolution': '1.50'}
# PDB code: 2b1q, Affinity Data {'Ki': 0.026000000000000002, 'resolution': '2.20'}
# PDB code: 1w8m, Affinity Data {'Ki': 0.025, 'resolution': '1.65'}
# PDB code: 3itc, Affinity Data {'Ki': 0.025, 'resolution': '1.70'}
# PDB code: 2it4, Affinity Data {'Ki': 0.024100000000000003, 'resolution': '2.00'}
# PDB code: 5k5c, Affinity Data {'IC50': 0.024, 'resolution': '1.85'}
# PDB code: 1a7t, Affinity Data {'Ki': 0.023, 'resolution': '1.85'}
# PDB code: 4d63, Affinity Data {'Kd': 0.023, 'resolution': '2.20'}
# PDB code: 1hgj, Affinity Data {'Kd': 0.022, 'resolution': '2.70'}
# PDB code: 1rdj, Affinity Data {'Ki': 0.0217, 'resolution': '1.80'}
# PDB code: 2o9r, Affinity Data {'Ki': 0.021, 'resolution': '2.30'}
# PDB code: 4qsw, Affinity Data {'Kd': 0.021, 'resolution': '1.80'}
# PDB code: 2sfp, Affinity Data {'Ki': 0.02, 'resolution': '1.90'}
# PDB code: 3gf2, Affinity Data {'Kd': 0.02, 'resolution': '1.80'}
# PDB code: 3oay, Affinity Data {'IC50': 0.02, 'resolution': '1.95'}
# PDB code: 4tyb, Affinity Data {'Kd': 0.019989999999999997, 'resolution': '2.93'}
# PDB code: 6cex, Affinity Data {'Kd': 0.02, 'resolution': '2.57'}
# PDB code: 6cf5, Affinity Data {'Kd': 0.02, 'resolution': '2.04'}
# PDB code: 3g6m, Affinity Data {'Ki': 0.0197, 'resolution': '1.65'}
# PDB code: 2hdr, Affinity Data {'Ki': 0.019, 'resolution': '2.20'}
# PDB code: 3ern, Affinity Data {'Kd': 0.01891, 'resolution': '2.10'}
# PDB code: 3vzg, Affinity Data {'Kd': 0.019, 'resolution': '2.70'}
# PDB code: 3zst, Affinity Data {'IC50': 0.019, 'resolution': '2.30'}
# PDB code: 5y61, Affinity Data {'Kd': 0.019100000000000002, 'resolution': '2.99'}
# PDB code: 1u2y, Affinity Data {'Ki': 0.018000000000000002, 'resolution': '1.95'}
# PDB code: 4qsx, Affinity Data {'Kd': 0.018000000000000002, 'resolution': '1.93'}
# PDB code: 5y62, Affinity Data {'Kd': 0.0184, 'resolution': '3.00'}
# PDB code: 5ggj, Affinity Data {'Kd': 0.01778, 'resolution': '1.42'}
# PDB code: 5zef, Affinity Data {'IC50': 0.0179, 'resolution': '2.01'}
# PDB code: 4bgx, Affinity Data {'Kd': 0.017, 'resolution': '2.48'}
# PDB code: 3f39, Affinity Data {'Kd': 0.0165, 'resolution': '1.85'}
# PDB code: 5ggl, Affinity Data {'Kd': 0.01652, 'resolution': '1.27'}
# PDB code: 2zgm, Affinity Data {'Ki': 0.016399999999999998, 'resolution': '1.90'}
# PDB code: 1ga8, Affinity Data {'Ki': 0.016, 'resolution': '2.00'}
# PDB code: 3rxh, Affinity Data {'IC50': 0.0157, 'resolution': '1.70'}
# PDB code: 1af6, Affinity Data {'Kd': 0.015, 'resolution': '2.40'}
# PDB code: 1bra, Affinity Data {'Ki': 0.015, 'resolution': '2.20'}
# PDB code: 1d5r, Affinity Data {'Ki': 0.015, 'resolution': '2.10'}
# PDB code: 1y1m, Affinity Data {'Ki': 0.015300000000000001, 'resolution': '1.80'}
# PDB code: 3eqb, Affinity Data {'IC50': 0.015, 'resolution': '2.62'}
# PDB code: 4ahv, Affinity Data {'Kd': 0.015, 'resolution': '1.80'}
# PDB code: 1rdn, Affinity Data {'Ki': 0.014400000000000001, 'resolution': '1.80'}
# PDB code: 1fd7, Affinity Data {'IC50': 0.014, 'resolution': '1.80'}
# PDB code: 3khv, Affinity Data {'Ki': 0.01399, 'resolution': '2.35'}
# PDB code: 1mwt, Affinity Data {'Kd': 0.013300000000000001, 'resolution': '2.45'}
# PDB code: 1tnl, Affinity Data {'Ki': 0.013300000000000001, 'resolution': '1.90'}
# PDB code: 2ay2, Affinity Data {'Kd': 0.0131, 'resolution': '2.40'}
# PDB code: 4x8s, Affinity Data {'Ki': 0.013000000000000001, 'resolution': '2.10'}
# PDB code: 1f2p, Affinity Data {'Ki': 0.0127, 'resolution': '1.80'}
# PDB code: 4mrh, Affinity Data {'Kd': 0.0126, 'resolution': '1.12'}
# PDB code: 1f2o, Affinity Data {'Ki': 0.012400000000000001, 'resolution': '1.70'}
# PDB code: 1efi, Affinity Data {'IC50': 0.012, 'resolution': '1.60'}
# PDB code: 3ehn, Affinity Data {'Kd': 0.012, 'resolution': '2.80'}
# PDB code: 4bh3, Affinity Data {'Kd': 0.012, 'resolution': '2.00'}
# PDB code: 2rjr, Affinity Data {'IC50': 0.0116, 'resolution': '2.10'}
# PDB code: 5nn4, Affinity Data {'Kd': 0.01157, 'resolution': '1.83'}
# PDB code: 4mrf, Affinity Data {'Kd': 0.0112, 'resolution': '1.55'}
# PDB code: 6abk, Affinity Data {'Kd': 0.011300000000000001, 'resolution': '1.58'}
# PDB code: 1tnj, Affinity Data {'Ki': 0.011, 'resolution': '1.80'}
# PDB code: 2gga, Affinity Data {'IC50': 0.011, 'resolution': '1.70'}
# PDB code: 5oxn, Affinity Data {'Kd': 0.01095, 'resolution': '2.20'}
# PDB code: 1wdq, Affinity Data {'Kd': 0.01045, 'resolution': '1.28'}
# PDB code: 6h7u, Affinity Data {'IC50': 0.010400000000000001, 'resolution': '2.80'}
# PDB code: 6hzp, Affinity Data {'IC50': 0.010400000000000001, 'resolution': '2.50'}
# PDB code: 3i3d, Affinity Data {'Ki': 0.0103, 'resolution': '2.20'}
# PDB code: 1gbt, Affinity Data {'Ki': 0.01, 'resolution': '2.00'}
# PDB code: 1ing, Affinity Data {'IC50': 0.01, 'resolution': '2.40'}
# PDB code: 2bmv, Affinity Data {'Kd': 0.01, 'resolution': '2.11'}
# PDB code: 2hds, Affinity Data {'Ki': 0.01, 'resolution': '1.16'}
# PDB code: 2r58, Affinity Data {'Kd': 0.01, 'resolution': '2.00'}
# PDB code: 3c2f, Affinity Data {'Kd': 0.0101, 'resolution': '2.35'}
# PDB code: 3g2y, Affinity Data {'Ki': 0.01, 'resolution': '1.31'}
# PDB code: 3pce, Affinity Data {'Ki': 0.01, 'resolution': '2.06'}
# PDB code: 3rv3, Affinity Data {'IC50': 0.01, 'resolution': '1.91'}
# PDB code: 4awj, Affinity Data {'Kd': 0.01, 'resolution': '2.50'}
# PDB code: 4ctk, Affinity Data {'IC50': 0.01, 'resolution': '1.53'}
# PDB code: 4kz5, Affinity Data {'Ki': 0.01, 'resolution': '1.35'}
# PDB code: 4qsu, Affinity Data {'Kd': 0.01, 'resolution': '1.90'}
# PDB code: 4qsv, Affinity Data {'Kd': 0.01, 'resolution': '1.90'}
# PDB code: 4u58, Affinity Data {'Kd': 0.01, 'resolution': '2.56'}
# PDB code: 4y4g, Affinity Data {'Kd': 0.01, 'resolution': '1.44'}
# PDB code: 6evq, Affinity Data {'Kd': 0.01, 'resolution': 'NMR'}
# PDB code: 6ra1, Affinity Data {'Kd': 0.01, 'resolution': '2.00'}
# PDB code: 4ty8, Affinity Data {'Kd': 0.00931, 'resolution': '2.78'}
# PDB code: 5ekx, Affinity Data {'IC50': 0.009300000000000001, 'resolution': '1.76'}
# PDB code: 5nzq, Affinity Data {'Kd': 0.009300000000000001, 'resolution': '1.50'}
# PDB code: 2ks9, Affinity Data {'Ki': 0.00902, 'resolution': 'NMR'}
# PDB code: 1jfh, Affinity Data {'Ki': 0.009000000000000001, 'resolution': '2.03'}
# PDB code: 4e4a, Affinity Data {'IC50': 0.009000000000000001, 'resolution': '1.45'}
# PDB code: 4ty9, Affinity Data {'Kd': 0.008960000000000001, 'resolution': '2.78'}
# PDB code: 4x8t, Affinity Data {'Kd': 0.0089, 'resolution': '2.20'}
# PDB code: 5eiw, Affinity Data {'IC50': 0.009000000000000001, 'resolution': '1.61'}
# PDB code: 1qq9, Affinity Data {'Ki': 0.0087, 'resolution': '1.53'}
# PDB code: 1rdi, Affinity Data {'Ki': 0.0088, 'resolution': '1.80'}
# PDB code: 2zg3, Affinity Data {'Kd': 0.0087, 'resolution': '3.00'}
# PDB code: 4u54, Affinity Data {'Kd': 0.0087, 'resolution': '2.41'}
# PDB code: 3ao4, Affinity Data {'Kd': 0.0085, 'resolution': '1.95'}
# PDB code: 4b0c, Affinity Data {'Kd': 0.0085, 'resolution': '2.70'}
# PDB code: 3rxp, Affinity Data {'IC50': 0.0083, 'resolution': '1.60'}
# PDB code: 5tyh, Affinity Data {'IC50': 0.008400000000000001, 'resolution': '2.10'}
# PDB code: 1njj, Affinity Data {'Ki': 0.008, 'resolution': '2.45'}
# PDB code: 2zg1, Affinity Data {'Kd': 0.008, 'resolution': '2.70'}
# PDB code: 4aml, Affinity Data {'IC50': 0.008, 'resolution': '1.60'}
# PDB code: 4cs9, Affinity Data {'Kd': 0.008, 'resolution': '2.01'}
# PDB code: 6r49, Affinity Data {'IC50': 0.008, 'resolution': '2.21'}
# PDB code: 3uf9, Affinity Data {'Ki': 0.0077800000000000005, 'resolution': '2.68'}
# PDB code: 6aao, Affinity Data {'Kd': 0.0078, 'resolution': '1.40'}
# PDB code: 1qx1, Affinity Data {'Ki': 0.0075, 'resolution': '1.30'}
# PDB code: 2w8w, Affinity Data {'Kd': 0.0075, 'resolution': '2.14'}
# PDB code: 3gv9, Affinity Data {'Ki': 0.0075, 'resolution': '1.80'}
# PDB code: 6r9u, Affinity Data {'Kd': 0.0075, 'resolution': '1.26'}
# PDB code: 1p2g, Affinity Data {'Ki': 0.0074, 'resolution': '2.30'}
# PDB code: 6gz9, Affinity Data {'IC50': 0.0074, 'resolution': '3.10'}
# PDB code: 6abx, Affinity Data {'Ki': 0.00719, 'resolution': '1.70'}
# PDB code: 6dim, Affinity Data {'IC50': 0.007200000000000001, 'resolution': '1.81'}
# PDB code: 6djd, Affinity Data {'IC50': 0.007200000000000001, 'resolution': '1.78'}
# PDB code: 1uxb, Affinity Data {'Kd': 0.007, 'resolution': '1.75'}
# PDB code: 3rxg, Affinity Data {'IC50': 0.0070999999999999995, 'resolution': '1.70'}
# PDB code: 4b0j, Affinity Data {'Kd': 0.0070999999999999995, 'resolution': '2.50'}
# PDB code: 4q90, Affinity Data {'Ki': 0.007, 'resolution': '1.54'}
# PDB code: 5cs3, Affinity Data {'Kd': 0.007, 'resolution': '2.50'}
# PDB code: 6fap, Affinity Data {'Kd': 0.0070999999999999995, 'resolution': '2.70'}
# PDB code: 6fi1, Affinity Data {'Kd': 0.0070999999999999995, 'resolution': '2.70'}
# PDB code: 6r9s, Affinity Data {'Kd': 0.0070999999999999995, 'resolution': '2.00'}
# PDB code: 2ay9, Affinity Data {'Kd': 0.006900000000000001, 'resolution': '2.50'}
# PDB code: 4tim, Affinity Data {'Ki': 0.006900000000000001, 'resolution': '2.40'}
# PDB code: 5fe6, Affinity Data {'Kd': 0.0069099999999999995, 'resolution': '1.77'}
# PDB code: 6ghj, Affinity Data {'Kd': 0.006889999999999999, 'resolution': '2.26'}
# PDB code: 3gqz, Affinity Data {'Ki': 0.0067, 'resolution': '1.80'}
# PDB code: 4y3j, Affinity Data {'Kd': 0.0068, 'resolution': '1.31'}
# PDB code: 5oxk, Affinity Data {'Kd': 0.0068200000000000005, 'resolution': '2.38'}
# PDB code: 5z5f, Affinity Data {'Ki': 0.0068, 'resolution': '2.10'}
# PDB code: 6gmx, Affinity Data {'Kd': 0.0067, 'resolution': '2.53'}
# PDB code: 3l7d, Affinity Data {'Ki': 0.00655, 'resolution': '2.00'}
# PDB code: 6g47, Affinity Data {'Kd': 0.0066, 'resolution': '1.50'}
# PDB code: 4ahr, Affinity Data {'Kd': 0.006500000000000001, 'resolution': '1.90'}
# PDB code: 4ahs, Affinity Data {'Kd': 0.0064, 'resolution': '1.75'}
# PDB code: 4amx, Affinity Data {'Ki': 0.006500000000000001, 'resolution': '2.10'}
# PDB code: 4jdf, Affinity Data {'Kd': 0.0064, 'resolution': '1.69'}
# PDB code: 4mre, Affinity Data {'Kd': 0.0064, 'resolution': '1.58'}
# PDB code: 5nzp, Affinity Data {'Kd': 0.006500000000000001, 'resolution': '1.30'}
# PDB code: 1w1v, Affinity Data {'IC50': 0.0063, 'resolution': '1.85'}
# PDB code: 2vvo, Affinity Data {'IC50': 0.0063, 'resolution': '1.85'}
# PDB code: 4eh8, Affinity Data {'IC50': 0.006247, 'resolution': '2.20'}
# PDB code: 1x8d, Affinity Data {'Kd': 0.0061600000000000005, 'resolution': '1.80'}
# PDB code: 4g0z, Affinity Data {'Kd': 0.00613, 'resolution': '1.75'}
# PDB code: 1icj, Affinity Data {'Ki': 0.006, 'resolution': '1.90'}
# PDB code: 1m0n, Affinity Data {'Ki': 0.006, 'resolution': '2.20'}
# PDB code: 2aac, Affinity Data {'Kd': 0.006, 'resolution': '1.60'}
# PDB code: 4aci, Affinity Data {'Kd': 0.006, 'resolution': '1.65'}
# PDB code: 4uru, Affinity Data {'Kd': 0.006, 'resolution': '2.83'}
# PDB code: 4ury, Affinity Data {'Kd': 0.006, 'resolution': '2.47'}
# PDB code: 4x11, Affinity Data {'Kd': 0.006, 'resolution': '2.30'}
# PDB code: 5fsb, Affinity Data {'Kd': 0.006, 'resolution': '1.65'}
# PDB code: 5hcl, Affinity Data {'IC50': 0.006, 'resolution': '1.50'}
# PDB code: 5jqb, Affinity Data {'Kd': 0.006, 'resolution': '2.68'}
# PDB code: 1ajp, Affinity Data {'Ki': 0.00585, 'resolution': '2.31'}
# PDB code: 2igv, Affinity Data {'Kd': 0.005900000000000001, 'resolution': '1.67'}
# PDB code: 3ao5, Affinity Data {'Kd': 0.005900000000000001, 'resolution': '1.80'}
# PDB code: 3i3b, Affinity Data {'Ki': 0.005900000000000001, 'resolution': '2.20'}
# PDB code: 1rdl, Affinity Data {'Ki': 0.0057, 'resolution': '1.70'}
# PDB code: 2ay8, Affinity Data {'Kd': 0.0058, 'resolution': '2.20'}
# PDB code: 2os9, Affinity Data {'IC50': 0.0057, 'resolution': '1.70'}
# PDB code: 5f6v, Affinity Data {'IC50': 0.0058, 'resolution': '1.49'}
# PDB code: 5m9w, Affinity Data {'Kd': 0.0057, 'resolution': '1.21'}
# PDB code: 5nzo, Affinity Data {'Kd': 0.0058, 'resolution': '1.29'}
# PDB code: 1ukt, Affinity Data {'IC50': 0.0056, 'resolution': '2.20'}
# PDB code: 1ew8, Affinity Data {'Ki': 0.0055, 'resolution': '2.20'}
# PDB code: 3ao1, Affinity Data {'Kd': 0.0055, 'resolution': '1.90'}
# PDB code: 4eh9, Affinity Data {'IC50': 0.0054529999999999995, 'resolution': '2.10'}
# PDB code: 4np2, Affinity Data {'Kd': 0.0055, 'resolution': '1.75'}
# PDB code: 5v6u, Affinity Data {'Ki': 0.00547, 'resolution': '2.80'}
# PDB code: 1hge, Affinity Data {'Kd': 0.0054, 'resolution': '2.60'}
# PDB code: 1uto, Affinity Data {'Kd': 0.00532, 'resolution': '1.15'}
# PDB code: 4ahu, Affinity Data {'Kd': 0.0054, 'resolution': '1.90'}
# PDB code: 4mfe, Affinity Data {'Ki': 0.0054, 'resolution': '2.61'}
# PDB code: 1ps3, Affinity Data {'Ki': 0.005200000000000001, 'resolution': '1.80'}
# PDB code: 2rjs, Affinity Data {'IC50': 0.0053, 'resolution': '2.40'}
# PDB code: 3fu0, Affinity Data {'IC50': 0.005307999999999999, 'resolution': '1.80'}
# PDB code: 3ip8, Affinity Data {'Ki': 0.005200000000000001, 'resolution': '1.50'}
# PDB code: 2ay1, Affinity Data {'Kd': 0.00514, 'resolution': '2.20'}
# PDB code: 4ddk, Affinity Data {'Kd': 0.0050999999999999995, 'resolution': '1.75'}
# PDB code: 4ehv, Affinity Data {'IC50': 0.005103, 'resolution': '1.60'}
# PDB code: 5fnj, Affinity Data {'Kd': 0.00515, 'resolution': '1.67'}
# PDB code: 1hyv, Affinity Data {'IC50': 0.005, 'resolution': '1.70'}
# PDB code: 1inh, Affinity Data {'IC50': 0.005, 'resolution': '2.40'}
# PDB code: 1jdj, Affinity Data {'IC50': 0.005, 'resolution': '2.20'}
# PDB code: 1n1g, Affinity Data {'IC50': 0.005, 'resolution': '2.50'}
# PDB code: 1o4g, Affinity Data {'IC50': 0.005, 'resolution': '1.55'}
# PDB code: 1uxa, Affinity Data {'Kd': 0.005, 'resolution': '1.50'}
# PDB code: 1w1p, Affinity Data {'IC50': 0.005, 'resolution': '2.10'}
# PDB code: 2ay7, Affinity Data {'Kd': 0.005, 'resolution': '2.40'}
# PDB code: 2hdu, Affinity Data {'Ki': 0.005, 'resolution': '1.49'}
# PDB code: 2xix, Affinity Data {'IC50': 0.005, 'resolution': '2.40'}
# PDB code: 2xlc, Affinity Data {'Ki': 0.005, 'resolution': '2.70'}
# PDB code: 3dyo, Affinity Data {'Ki': 0.005, 'resolution': '1.80'}
# PDB code: 3kgq, Affinity Data {'Ki': 0.005, 'resolution': '1.70'}
# PDB code: 3mhw, Affinity Data {'Ki': 0.005030000000000001, 'resolution': '1.45'}
# PDB code: 3pcg, Affinity Data {'Ki': 0.005, 'resolution': '1.96'}
# PDB code: 3rv4, Affinity Data {'Ki': 0.005, 'resolution': '1.98'}
# PDB code: 4b6e, Affinity Data {'IC50': 0.005, 'resolution': '2.46'}
# PDB code: 4e3d, Affinity Data {'IC50': 0.005, 'resolution': '1.60'}
# PDB code: 4g0y, Affinity Data {'Kd': 0.0049900000000000005, 'resolution': '1.65'}
# PDB code: 4jsz, Affinity Data {'Ki': 0.005, 'resolution': '1.90'}
# PDB code: 4led, Affinity Data {'Kd': 0.005, 'resolution': '2.37'}
# PDB code: 4wh7, Affinity Data {'IC50': 0.005, 'resolution': '1.62'}
# PDB code: 5enc, Affinity Data {'IC50': 0.005, 'resolution': '1.59'}
# PDB code: 5eni, Affinity Data {'IC50': 0.005, 'resolution': '1.69'}
# PDB code: 5enj, Affinity Data {'IC50': 0.005, 'resolution': '1.63'}
# PDB code: 5g42, Affinity Data {'Kd': 0.005, 'resolution': '1.72'}
# PDB code: 6au2, Affinity Data {'Kd': 0.005, 'resolution': '1.63'}
# PDB code: 6gmq, Affinity Data {'Kd': 0.005, 'resolution': '2.76'}
# PDB code: 1m0o, Affinity Data {'Ki': 0.004900000000000001, 'resolution': '2.40'}
# PDB code: 4y0a, Affinity Data {'Ki': 0.0049499999999999995, 'resolution': '1.91'}
# PDB code: 5mz8, Affinity Data {'Kd': 0.004900000000000001, 'resolution': '2.20'}
# PDB code: 2qve, Affinity Data {'IC50': 0.0048, 'resolution': '2.00'}
# PDB code: 5aol, Affinity Data {'Kd': 0.0048, 'resolution': '1.50'}
# PDB code: 1z6d, Affinity Data {'Ki': 0.0046, 'resolution': '1.54'}
# PDB code: 4iie, Affinity Data {'Ki': 0.0046, 'resolution': '2.00'}
# PDB code: 5elf, Affinity Data {'Kd': 0.00457, 'resolution': '1.55'}
# PDB code: 1qi0, Affinity Data {'Ki': 0.0045000000000000005, 'resolution': '2.10'}
# PDB code: 3gtc, Affinity Data {'Ki': 0.0045000000000000005, 'resolution': '1.90'}
# PDB code: 4k3k, Affinity Data {'IC50': 0.00444, 'resolution': '1.85'}
# PDB code: 4y3y, Affinity Data {'Kd': 0.0045000000000000005, 'resolution': '1.35'}
# PDB code: 1o4j, Affinity Data {'IC50': 0.0044, 'resolution': '1.70'}
# PDB code: 3g2z, Affinity Data {'Ki': 0.0044, 'resolution': '1.50'}
# PDB code: 5fsc, Affinity Data {'Kd': 0.0044, 'resolution': '1.95'}
# PDB code: 3t0d, Affinity Data {'Ki': 0.0043, 'resolution': '1.93'}
# PDB code: 4jck, Affinity Data {'Kd': 0.0043, 'resolution': '1.15'}
# PDB code: 6rnt, Affinity Data {'Kd': 0.0043, 'resolution': '1.80'}
# PDB code: 3f6e, Affinity Data {'Kd': 0.00414, 'resolution': '1.34'}
# PDB code: 4aj2, Affinity Data {'Kd': 0.0042, 'resolution': '1.75'}
# PDB code: 6md8, Affinity Data {'Ki': 0.0042, 'resolution': '1.40'}
# PDB code: 1f73, Affinity Data {'Ki': 0.0040999999999999995, 'resolution': '1.95'}
# PDB code: 1nwl, Affinity Data {'Ki': 0.0040999999999999995, 'resolution': '2.40'}
# PDB code: 4nyt, Affinity Data {'Kd': 0.0040999999999999995, 'resolution': '2.25'}
# PDB code: 4tya, Affinity Data {'Kd': 0.00404, 'resolution': '2.94'}
# PDB code: 2wi1, Affinity Data {'IC50': 0.004, 'resolution': '2.30'}
# PDB code: 3dxg, Affinity Data {'Ki': 0.004, 'resolution': '1.39'}
# PDB code: 3l7b, Affinity Data {'Ki': 0.00401, 'resolution': '2.00'}
# PDB code: 3pcb, Affinity Data {'Ki': 0.004, 'resolution': '2.19'}
# PDB code: 3t2t, Affinity Data {'Kd': 0.004, 'resolution': '1.90'}
# PDB code: 4u5l, Affinity Data {'Kd': 0.004, 'resolution': '2.53'}
# PDB code: 4y38, Affinity Data {'Kd': 0.004, 'resolution': '1.10'}
# PDB code: 4zsm, Affinity Data {'IC50': 0.004, 'resolution': '1.96'}
# PDB code: 1o4r, Affinity Data {'IC50': 0.0039, 'resolution': '1.50'}
# PDB code: 2wsx, Affinity Data {'Kd': 0.0039, 'resolution': '3.50'}
# PDB code: 4u5s, Affinity Data {'Kd': 0.0039, 'resolution': '2.12'}
# PDB code: 6aaq, Affinity Data {'Kd': 0.0039, 'resolution': '1.55'}
# PDB code: 4u5o, Affinity Data {'Kd': 0.0038, 'resolution': '2.00'}
# PDB code: 5os3, Affinity Data {'Kd': 0.003753, 'resolution': '1.81'}
# PDB code: 6mli, Affinity Data {'Kd': 0.0037, 'resolution': '1.88'}
# PDB code: 1o4h, Affinity Data {'IC50': 0.0036000000000000003, 'resolution': '2.25'}
# PDB code: 1oba, Affinity Data {'Kd': 0.0036000000000000003, 'resolution': '2.45'}
# PDB code: 1t4s, Affinity Data {'Ki': 0.0036000000000000003, 'resolution': '2.80'}
# PDB code: 2i2b, Affinity Data {'Ki': 0.0036000000000000003, 'resolution': '2.10'}
# PDB code: 2xiy, Affinity Data {'IC50': 0.0036, 'resolution': '2.20'}
# PDB code: 3ked, Affinity Data {'IC50': 0.0036000000000000003, 'resolution': '2.30'}
# PDB code: 3l7c, Affinity Data {'Ki': 0.00367, 'resolution': '1.93'}
# PDB code: 3mjl, Affinity Data {'Ki': 0.0036000000000000003, 'resolution': '1.90'}
# PDB code: 4d62, Affinity Data {'Kd': 0.00364, 'resolution': '2.50'}
# PDB code: 1gbq, Affinity Data {'Kd': 0.0035, 'resolution': 'NMR'}
# PDB code: 1o4o, Affinity Data {'IC50': 0.0035, 'resolution': '1.70'}
# PDB code: 2aez, Affinity Data {'Ki': 0.0035, 'resolution': '3.05'}
# PDB code: 3l79, Affinity Data {'Ki': 0.00346, 'resolution': '1.86'}
# PDB code: 4ah9, Affinity Data {'Kd': 0.0035, 'resolution': '1.70'}
# PDB code: 4ddm, Affinity Data {'Kd': 0.0035, 'resolution': '1.83'}
# PDB code: 4eh6, Affinity Data {'IC50': 0.0034709999999999997, 'resolution': '2.10'}
# PDB code: 4x8u, Affinity Data {'Ki': 0.0035, 'resolution': '2.10'}
# PDB code: 5aqh, Affinity Data {'Kd': 0.0035, 'resolution': '2.00'}
# PDB code: 1tok, Affinity Data {'Kd': 0.0034, 'resolution': '1.85'}
# PDB code: 1utl, Affinity Data {'Kd': 0.0034100000000000003, 'resolution': '1.70'}
# PDB code: 3rik, Affinity Data {'IC50': 0.0034, 'resolution': '2.48'}
# PDB code: 4gne, Affinity Data {'Kd': 0.0034, 'resolution': '1.47'}
# PDB code: 4y4j, Affinity Data {'Kd': 0.0034, 'resolution': '1.03'}
# PDB code: 5dv4, Affinity Data {'IC50': 0.0033699999999999997, 'resolution': '1.80'}
# PDB code: 5jal, Affinity Data {'Kd': 0.0034, 'resolution': '2.06'}
# PDB code: 6fhq, Affinity Data {'Kd': 0.0034, 'resolution': '1.95'}
# PDB code: 1gyx, Affinity Data {'Ki': 0.0033, 'resolution': '1.35'}
# PDB code: 4u5n, Affinity Data {'Kd': 0.0033, 'resolution': '2.31'}
# PDB code: 4ze6, Affinity Data {'Kd': 0.0033, 'resolution': '1.17'}
# PDB code: 5mn1, Affinity Data {'Kd': 0.0033, 'resolution': '0.79'}
# PDB code: 5mnb, Affinity Data {'Kd': 0.0033, 'resolution': '0.94'}
# PDB code: 5mnx, Affinity Data {'Kd': 0.0033, 'resolution': '1.42'}
# PDB code: 5mon, Affinity Data {'Kd': 0.0033, 'resolution': '0.94'}
# PDB code: 1o4q, Affinity Data {'IC50': 0.0032, 'resolution': '1.70'}
# PDB code: 4efk, Affinity Data {'Kd': 0.0032, 'resolution': '1.70'}
# PDB code: 4ej2, Affinity Data {'Ki': 0.003204, 'resolution': '2.65'}
# PDB code: 4kz7, Affinity Data {'Ki': 0.0032, 'resolution': '1.43'}
# PDB code: 6c3n, Affinity Data {'Kd': 0.0032, 'resolution': '2.53'}
# PDB code: 1ai4, Affinity Data {'Ki': 0.00313, 'resolution': '2.35'}
# PDB code: 3g30, Affinity Data {'Ki': 0.0031000000000000003, 'resolution': '1.80'}
# PDB code: 4ctj, Affinity Data {'IC50': 0.0031200000000000004, 'resolution': '1.47'}
# PDB code: 6dji, Affinity Data {'IC50': 0.0031000000000000003, 'resolution': '1.75'}
# PDB code: 1rq2, Affinity Data {'IC50': 0.003, 'resolution': '1.86'}
# PDB code: 1wdr, Affinity Data {'Kd': 0.0030499999999999998, 'resolution': '1.35'}
# PDB code: 3ad7, Affinity Data {'Kd': 0.0030099999999999997, 'resolution': '2.20'}
# PDB code: 3bf1, Affinity Data {'Kd': 0.003, 'resolution': '2.30'}
# PDB code: 3fq7, Affinity Data {'IC50': 0.003, 'resolution': '2.15'}
# PDB code: 3gr2, Affinity Data {'Ki': 0.003, 'resolution': '1.80'}
# PDB code: 3mfv, Affinity Data {'Ki': 0.003, 'resolution': '1.90'}
# PDB code: 3vdb, Affinity Data {'Ki': 0.0030299999999999997, 'resolution': '2.05'}
# PDB code: 4e3f, Affinity Data {'IC50': 0.003, 'resolution': '1.50'}
# PDB code: 4g0q, Affinity Data {'Kd': 0.003, 'resolution': '1.80'}
# PDB code: 4urz, Affinity Data {'Kd': 0.003, 'resolution': '2.24'}
# PDB code: 5f6d, Affinity Data {'IC50': 0.003, 'resolution': '1.55'}
# PDB code: 5f6u, Affinity Data {'IC50': 0.003, 'resolution': '1.55'}
# PDB code: 4hj2, Affinity Data {'Kd': 0.0029500000000000004, 'resolution': '2.10'}
# PDB code: 1iup, Affinity Data {'Ki': 0.0029, 'resolution': '1.60'}
# PDB code: 1il3, Affinity Data {'IC50': 0.0028, 'resolution': '2.80'}
# PDB code: 1kf0, Affinity Data {'Kd': 0.0028, 'resolution': '2.50'}
# PDB code: 3b3s, Affinity Data {'Ki': 0.0028, 'resolution': '1.18'}
# PDB code: 3ovn, Affinity Data {'Kd': 0.0028, 'resolution': '1.95'}
# PDB code: 5eif, Affinity Data {'IC50': 0.0028, 'resolution': '1.50'}
# PDB code: 5n53, Affinity Data {'Kd': 0.0028, 'resolution': '1.48'}
# PDB code: 5os0, Affinity Data {'Kd': 0.0027919999999999998, 'resolution': '1.74'}
# PDB code: 1gwv, Affinity Data {'Kd': 0.00268, 'resolution': '2.50'}
# PDB code: 2ria, Affinity Data {'IC50': 0.0027, 'resolution': '1.80'}
# PDB code: 2wq4, Affinity Data {'Kd': 0.0026999999999999997, 'resolution': '1.42'}
# PDB code: 3kgp, Affinity Data {'Ki': 0.00268, 'resolution': '2.35'}
# PDB code: 5v4q, Affinity Data {'Ki': 0.0027, 'resolution': '2.20'}
# PDB code: 6poq, Affinity Data {'Kd': 0.0026999999999999997, 'resolution': '1.80'}
# PDB code: 2ay5, Affinity Data {'Kd': 0.0026000000000000003, 'resolution': '2.40'}
# PDB code: 2jst, Affinity Data {'Kd': 0.0026000000000000003, 'resolution': 'NMR'}
# PDB code: 3gvb, Affinity Data {'Ki': 0.0026000000000000003, 'resolution': '1.80'}
# PDB code: 4o3a, Affinity Data {'Ki': 0.00257, 'resolution': '1.80'}
# PDB code: 4o3c, Affinity Data {'Ki': 0.00257, 'resolution': '1.50'}
# PDB code: 4wef, Affinity Data {'Ki': 0.002577, 'resolution': '2.50'}
# PDB code: 5tpb, Affinity Data {'Kd': 0.0026000000000000003, 'resolution': '2.60'}
# PDB code: 1o4p, Affinity Data {'IC50': 0.0025, 'resolution': '1.90'}
# PDB code: 2c4v, Affinity Data {'Ki': 0.0025, 'resolution': '2.50'}
# PDB code: 2r5a, Affinity Data {'Kd': 0.0025, 'resolution': '2.30'}
# PDB code: 3gwv, Affinity Data {'IC50': 0.00254, 'resolution': '2.35'}
# PDB code: 3rxf, Affinity Data {'IC50': 0.0025, 'resolution': '1.70'}
# PDB code: 4up5, Affinity Data {'Kd': 0.0025, 'resolution': '1.65'}
# PDB code: 5g46, Affinity Data {'Kd': 0.0025, 'resolution': '1.76'}
# PDB code: 6mia, Affinity Data {'Ki': 0.0025399999999999997, 'resolution': '1.40'}
# PDB code: 1cze, Affinity Data {'Kd': 0.0024, 'resolution': '2.40'}
# PDB code: 1w1y, Affinity Data {'IC50': 0.0024, 'resolution': '1.85'}
# PDB code: 2kfh, Affinity Data {'Kd': 0.0024, 'resolution': 'NMR'}
# PDB code: 3f37, Affinity Data {'Kd': 0.0024, 'resolution': '1.54'}
# PDB code: 3f38, Affinity Data {'Kd': 0.0024, 'resolution': '1.75'}
# PDB code: 3fk1, Affinity Data {'Ki': 0.00242, 'resolution': '1.70'}
# PDB code: 3rxl, Affinity Data {'IC50': 0.0024, 'resolution': '1.70'}
# PDB code: 4lnf, Affinity Data {'IC50': 0.0024, 'resolution': '2.95'}
# PDB code: 4lno, Affinity Data {'Kd': 0.0024, 'resolution': '2.90'}
# PDB code: 5foo, Affinity Data {'Ki': 0.0024, 'resolution': '2.10'}
# PDB code: 5lvd, Affinity Data {'Kd': 0.0024, 'resolution': '1.25'}
# PDB code: 1ajn, Affinity Data {'Ki': 0.00232, 'resolution': '2.36'}
# PDB code: 1g5f, Affinity Data {'Ki': 0.00231, 'resolution': '1.80'}
# PDB code: 1o4i, Affinity Data {'IC50': 0.0023, 'resolution': '1.75'}
# PDB code: 3p1d, Affinity Data {'IC50': 0.0023, 'resolution': '1.86'}
# PDB code: 4i8x, Affinity Data {'Kd': 0.0023, 'resolution': '2.23'}
# PDB code: 4q7w, Affinity Data {'Ki': 0.0023, 'resolution': '1.45'}
# PDB code: 4q8y, Affinity Data {'Ki': 0.0023, 'resolution': '1.45'}
# PDB code: 4ufl, Affinity Data {'Ki': 0.0023, 'resolution': '2.40'}
# PDB code: 6fhu, Affinity Data {'Kd': 0.0023, 'resolution': '2.00'}
# PDB code: 5ey0, Affinity Data {'Kd': 0.00226, 'resolution': '1.60'}
# PDB code: 1il5, Affinity Data {'IC50': 0.0022, 'resolution': '2.80'}
# PDB code: 3a1e, Affinity Data {'Kd': 0.0022, 'resolution': '1.95'}
# PDB code: 3rxb, Affinity Data {'IC50': 0.0022, 'resolution': '1.70'}
# PDB code: 4y2p, Affinity Data {'IC50': 0.0021999999999999997, 'resolution': '2.05'}
# PDB code: 5eld, Affinity Data {'Kd': 0.00219, 'resolution': '1.40'}
# PDB code: 3lvw, Affinity Data {'Ki': 0.0021200000000000004, 'resolution': '2.50'}
# PDB code: 6prt, Affinity Data {'IC50': 0.00212, 'resolution': '1.30'}
# PDB code: 1hgi, Affinity Data {'Kd': 0.0021000000000000003, 'resolution': '2.70'}
# PDB code: 1o8b, Affinity Data {'Ki': 0.0021000000000000003, 'resolution': '1.25'}
# PDB code: 2q72, Affinity Data {'IC50': 0.00209, 'resolution': '1.70'}
# PDB code: 3rxk, Affinity Data {'IC50': 0.0021000000000000003, 'resolution': '1.60'}
# PDB code: 4b3c, Affinity Data {'Kd': 0.0021000000000000003, 'resolution': '1.90'}
# PDB code: 4b3d, Affinity Data {'Kd': 0.0021000000000000003, 'resolution': '1.59'}
# PDB code: 5aqj, Affinity Data {'Kd': 0.0021, 'resolution': '1.96'}
# PDB code: 5aqp, Affinity Data {'Kd': 0.0021000000000000003, 'resolution': '2.08'}
# PDB code: 3elc, Affinity Data {'Kd': 0.00202, 'resolution': '2.50'}
# PDB code: 4usw, Affinity Data {'Kd': 0.0020299999999999997, 'resolution': '2.05'}
# PDB code: 5k5s, Affinity Data {'IC50': 0.00204, 'resolution': '2.60'}
# PDB code: 1br5, Affinity Data {'Ki': 0.002, 'resolution': '2.50'}
# PDB code: 1gym, Affinity Data {'IC50': 0.002, 'resolution': '2.20'}
# PDB code: 1lt5, Affinity Data {'IC50': 0.002, 'resolution': '1.70'}
# PDB code: 1tc1, Affinity Data {'IC50': 0.002, 'resolution': '1.41'}
# PDB code: 1ylv, Affinity Data {'Ki': 0.002, 'resolution': '2.15'}
# PDB code: 2fzc, Affinity Data {'Ki': 0.00199, 'resolution': '2.10'}
# PDB code: 2ha4, Affinity Data {'Kd': 0.002, 'resolution': '2.56'}
# PDB code: 2krd, Affinity Data {'Kd': 0.002, 'resolution': 'NMR'}
# PDB code: 2ohk, Affinity Data {'IC50': 0.002, 'resolution': '2.20'}
# PDB code: 2ow6, Affinity Data {'IC50': 0.002, 'resolution': '1.19'}
# PDB code: 2uyn, Affinity Data {'Kd': 0.002, 'resolution': '1.60'}
# PDB code: 3bra, Affinity Data {'Kd': 0.002, 'resolution': '2.30'}
# PDB code: 3ftz, Affinity Data {'IC50': 0.002, 'resolution': '2.00'}
# PDB code: 3fud, Affinity Data {'IC50': 0.002, 'resolution': '2.20'}
# PDB code: 3fuf, Affinity Data {'IC50': 0.002, 'resolution': '2.60'}
# PDB code: 3fuh, Affinity Data {'IC50': 0.002, 'resolution': '1.80'}
# PDB code: 3gk2, Affinity Data {'Kd': 0.002, 'resolution': '1.98'}
# PDB code: 3gsg, Affinity Data {'Ki': 0.002, 'resolution': '2.10'}
# PDB code: 3hvg, Affinity Data {'IC50': 0.002, 'resolution': '2.26'}
# PDB code: 3rqw, Affinity Data {'Kd': 0.002, 'resolution': '2.91'}
# PDB code: 3sl0, Affinity Data {'Ki': 0.002, 'resolution': '2.00'}
# PDB code: 3zsw, Affinity Data {'Kd': 0.002, 'resolution': '1.80'}
# PDB code: 3zsz, Affinity Data {'Kd': 0.002, 'resolution': '2.00'}
# PDB code: 3zt1, Affinity Data {'Kd': 0.002, 'resolution': '1.75'}
# PDB code: 4h4b, Affinity Data {'Ki': 0.002, 'resolution': '2.90'}
# PDB code: 4okp, Affinity Data {'Ki': 0.002, 'resolution': '1.37'}
# PDB code: 4old, Affinity Data {'Ki': 0.002, 'resolution': '1.48'}
# PDB code: 4wks, Affinity Data {'Ki': 0.002, 'resolution': '1.63'}
# PDB code: 4ypf, Affinity Data {'IC50': 0.002, 'resolution': '2.20'}
# PDB code: 4yrc, Affinity Data {'IC50': 0.002, 'resolution': '2.10'}
# PDB code: 4yrg, Affinity Data {'IC50': 0.002, 'resolution': '2.15'}
# PDB code: 4yrr, Affinity Data {'IC50': 0.002, 'resolution': '2.30'}
# PDB code: 5aok, Affinity Data {'Kd': 0.002, 'resolution': '1.35'}
# PDB code: 6fty, Affinity Data {'Kd': 0.002, 'resolution': '1.67'}
# PDB code: 6nmb, Affinity Data {'Ki': 0.0020099999999999996, 'resolution': '2.30'}
# PDB code: 4kpz, Affinity Data {'IC50': 0.00195, 'resolution': '2.09'}
# PDB code: 6poh, Affinity Data {'Kd': 0.00197, 'resolution': '1.67'}
# PDB code: 1pfu, Affinity Data {'Kd': 0.0019, 'resolution': '1.91'}
# PDB code: 2rkd, Affinity Data {'Ki': 0.0019, 'resolution': '1.90'}
# PDB code: 3p4r, Affinity Data {'Ki': 0.0019, 'resolution': '3.05'}
# PDB code: 5fsx, Affinity Data {'Kd': 0.0019, 'resolution': '2.00'}
# PDB code: 6dih, Affinity Data {'IC50': 0.0019, 'resolution': '1.78'}
# PDB code: 1dg9, Affinity Data {'Ki': 0.0018000000000000002, 'resolution': '1.90'}
# PDB code: 2qwb, Affinity Data {'Ki': 0.00182, 'resolution': '2.00'}
# PDB code: 2vyt, Affinity Data {'Kd': 0.00184, 'resolution': '1.90'}
# PDB code: 4m6u, Affinity Data {'Ki': 0.0018000000000000002, 'resolution': '1.80'}
# PDB code: 4ndu, Affinity Data {'Kd': 0.0018000000000000002, 'resolution': '1.30'}
# PDB code: 5os2, Affinity Data {'Kd': 0.001821, 'resolution': '1.92'}
# PDB code: 6a9c, Affinity Data {'Kd': 0.0018000000000000002, 'resolution': '1.98'}
# PDB code: 1rql, Affinity Data {'Ki': 0.0017900000000000001, 'resolution': '2.40'}
# PDB code: 5oyd, Affinity Data {'Kd': 0.0017800000000000001, 'resolution': '2.10'}
# PDB code: 6aan, Affinity Data {'Kd': 0.00176, 'resolution': '1.51'}
# PDB code: 1ny2, Affinity Data {'Ki': 0.00175, 'resolution': '2.30'}
# PDB code: 4bt5, Affinity Data {'Ki': 0.00172, 'resolution': '1.10'}
# PDB code: 5er4, Affinity Data {'Kd': 0.0017519999999999999, 'resolution': '1.81'}
# PDB code: 2bet, Affinity Data {'Ki': 0.0017, 'resolution': '2.20'}
# PDB code: 2p3o, Affinity Data {'IC50': 0.0017, 'resolution': '2.76'}
# PDB code: 3fcq, Affinity Data {'Ki': 0.0017, 'resolution': '1.75'}
# PDB code: 3l0n, Affinity Data {'IC50': 0.0016799999999999999, 'resolution': '1.74'}
# PDB code: 4a4h, Affinity Data {'Kd': 0.001706, 'resolution': 'NMR'}
# PDB code: 4g5y, Affinity Data {'Kd': 0.0017, 'resolution': '1.80'}
# PDB code: 4kz3, Affinity Data {'Ki': 0.0017, 'resolution': '1.67'}
# PDB code: 4urv, Affinity Data {'Kd': 0.0017, 'resolution': '2.58'}
# PDB code: 4ykk, Affinity Data {'Ki': 0.0017, 'resolution': '1.38'}
# PDB code: 5aqn, Affinity Data {'Kd': 0.0017, 'resolution': '2.45'}
# PDB code: 5oug, Affinity Data {'Kd': 0.00170344, 'resolution': '2.57'}
# PDB code: 6er4, Affinity Data {'Kd': 0.0017, 'resolution': '1.30'}
# PDB code: 6g24, Affinity Data {'Kd': 0.0017, 'resolution': '2.10'}
# PDB code: 2yiv, Affinity Data {'Ki': 0.00166, 'resolution': '1.28'}
# PDB code: 3ftw, Affinity Data {'IC50': 0.00167, 'resolution': '1.85'}
# PDB code: 4yrt, Affinity Data {'IC50': 0.00165, 'resolution': '2.05'}
# PDB code: 5os4, Affinity Data {'Kd': 0.001665, 'resolution': '1.88'}
# PDB code: 6aad, Affinity Data {'Kd': 0.0016200000000000001, 'resolution': '1.44'}
# PDB code: 2bge, Affinity Data {'IC50': 0.0016, 'resolution': '1.80'}
# PDB code: 2bza, Affinity Data {'Ki': 0.00158, 'resolution': '1.90'}
# PDB code: 3zt4, Affinity Data {'Kd': 0.00157, 'resolution': '2.20'}
# PDB code: 4kz8, Affinity Data {'Ki': 0.0016, 'resolution': '2.28'}
# PDB code: 4urw, Affinity Data {'Kd': 0.0016, 'resolution': '2.76'}
# PDB code: 4yw2, Affinity Data {'Kd': 0.0016, 'resolution': '2.00'}
# PDB code: 5fbi, Affinity Data {'Kd': 0.0015999999999999999, 'resolution': '1.47'}
# PDB code: 5fov, Affinity Data {'Kd': 0.0015899999999999998, 'resolution': '1.74'}
# PDB code: 5hki, Affinity Data {'Kd': 0.0016, 'resolution': '2.40'}
# PDB code: 5ofw, Affinity Data {'Kd': 0.0016, 'resolution': '1.50'}
# PDB code: 5zee, Affinity Data {'IC50': 0.00157, 'resolution': '1.74'}
# PDB code: 6rqk, Affinity Data {'Kd': 0.0016, 'resolution': '1.85'}
# PDB code: 3djx, Affinity Data {'Ki': 0.0015579, 'resolution': '1.69'}
# PDB code: 4eh4, Affinity Data {'IC50': 0.001534, 'resolution': '2.50'}
# PDB code: 4oyt, Affinity Data {'Ki': 0.0015500000000000002, 'resolution': '2.40'}
# PDB code: 4rrg, Affinity Data {'Kd': 0.0015385, 'resolution': '1.93'}
# PDB code: 1czc, Affinity Data {'Kd': 0.0015, 'resolution': '2.50'}
# PDB code: 1p17, Affinity Data {'Kd': 0.0015, 'resolution': '2.70'}
# PDB code: 2a3a, Affinity Data {'IC50': 0.0015, 'resolution': '2.10'}
# PDB code: 2rib, Affinity Data {'IC50': 0.0015, 'resolution': '1.80'}
# PDB code: 2w6z, Affinity Data {'IC50': 0.0015, 'resolution': '1.90'}
# PDB code: 2xj0, Affinity Data {'IC50': 0.0015, 'resolution': '3.10'}
# PDB code: 2yc0, Affinity Data {'IC50': 0.0015, 'resolution': '2.15'}
# PDB code: 3fue, Affinity Data {'IC50': 0.0015099999999999998, 'resolution': '2.38'}
# PDB code: 3lka, Affinity Data {'Kd': 0.0015, 'resolution': '1.80'}
# PDB code: 3ppr, Affinity Data {'Kd': 0.0015, 'resolution': '2.10'}
# PDB code: 4dsu, Affinity Data {'Kd': 0.0015, 'resolution': '1.70'}
# PDB code: 4k7i, Affinity Data {'Kd': 0.0015, 'resolution': '2.25'}
# PDB code: 4pb1, Affinity Data {'Kd': 0.00153, 'resolution': '2.80'}
# PDB code: 4z46, Affinity Data {'Kd': 0.00151, 'resolution': '1.85'}
# PDB code: 5aip, Affinity Data {'Kd': 0.0015, 'resolution': '2.30'}
# PDB code: 6cw4, Affinity Data {'Kd': 0.0015, 'resolution': 'NMR'}
# PDB code: 6evm, Affinity Data {'Kd': 0.0015, 'resolution': '2.00'}
# PDB code: 6mj7, Affinity Data {'Kd': 0.0015, 'resolution': '1.41'}
# PDB code: 6quw, Affinity Data {'Kd': 0.0015, 'resolution': '1.24'}
# PDB code: 4yz5, Affinity Data {'Kd': 0.00148, 'resolution': '2.27'}
# PDB code: 3fu3, Affinity Data {'IC50': 0.0014429999999999998, 'resolution': '2.00'}
# PDB code: 3moh, Affinity Data {'Ki': 0.00146, 'resolution': '2.10'}
# PDB code: 3zt2, Affinity Data {'Kd': 0.0014349999999999999, 'resolution': '1.70'}
# PDB code: 4cgj, Affinity Data {'Kd': 0.00146, 'resolution': '2.15'}
# PDB code: 1il4, Affinity Data {'IC50': 0.0014, 'resolution': '2.60'}
# PDB code: 2a29, Affinity Data {'Kd': 0.0014, 'resolution': 'NMR'}
# PDB code: 2ork, Affinity Data {'IC50': 0.0014, 'resolution': '1.89'}
# PDB code: 3atk, Affinity Data {'IC50': 0.0014, 'resolution': '1.74'}
# PDB code: 3k3g, Affinity Data {'IC50': 0.0014, 'resolution': '2.40'}
# PDB code: 3rxa, Affinity Data {'IC50': 0.0014, 'resolution': '1.70'}
# PDB code: 3udh, Affinity Data {'Kd': 0.0014, 'resolution': '1.70'}
# PDB code: 4luv, Affinity Data {'Kd': 0.0014, 'resolution': '1.40'}
# PDB code: 4mlt, Affinity Data {'Ki': 0.0014, 'resolution': '2.00'}
# PDB code: 4x47, Affinity Data {'IC50': 0.00141, 'resolution': '2.00'}
# PDB code: 4ym2, Affinity Data {'Kd': 0.0014, 'resolution': '2.10'}
# PDB code: 5aqo, Affinity Data {'Kd': 0.0014, 'resolution': '2.12'}
# PDB code: 5th4, Affinity Data {'Ki': 0.00142, 'resolution': '1.47'}
# PDB code: 6jjm, Affinity Data {'IC50': 0.0014, 'resolution': '2.05'}
# PDB code: 3qx8, Affinity Data {'Kd': 0.0013700000000000001, 'resolution': '2.30'}
# PDB code: 3zt3, Affinity Data {'Kd': 0.001375, 'resolution': '1.95'}
# PDB code: 4ouj, Affinity Data {'Kd': 0.00139, 'resolution': '1.46'}
# PDB code: 4pd5, Affinity Data {'Kd': 0.00137, 'resolution': '2.91'}
# PDB code: 5z1c, Affinity Data {'Ki': 0.00138, 'resolution': '1.45'}
# PDB code: 4fgz, Affinity Data {'IC50': 0.0013499999999999999, 'resolution': '1.99'}
# PDB code: 5thj, Affinity Data {'Ki': 0.0013499999999999999, 'resolution': '1.50'}
# PDB code: 1e34, Affinity Data {'Ki': 0.00132, 'resolution': '1.80'}
# PDB code: 2woq, Affinity Data {'Ki': 0.00133, 'resolution': '1.75'}
# PDB code: 4a4f, Affinity Data {'Kd': 0.001317, 'resolution': 'NMR'}
# PDB code: 4ucv, Affinity Data {'IC50': 0.00131, 'resolution': '2.60'}
# PDB code: 1cet, Affinity Data {'Ki': 0.0013000000000000002, 'resolution': '2.05'}
# PDB code: 1iih, Affinity Data {'Ki': 0.0013000000000000002, 'resolution': '2.20'}
# PDB code: 1ugp, Affinity Data {'Ki': 0.0013000000000000002, 'resolution': '1.63'}
# PDB code: 2k2r, Affinity Data {'Kd': 0.0013000000000000002, 'resolution': 'NMR'}
# PDB code: 2wpb, Affinity Data {'Ki': 0.0013000000000000002, 'resolution': '2.05'}
# PDB code: 2wtx, Affinity Data {'Ki': 0.0013000000000000002, 'resolution': '2.20'}
# PDB code: 3f36, Affinity Data {'Kd': 0.0013000000000000002, 'resolution': '1.70'}
# PDB code: 3g31, Affinity Data {'Ki': 0.0013000000000000002, 'resolution': '1.70'}
# PDB code: 4b35, Affinity Data {'Kd': 0.0013000000000000002, 'resolution': '1.40'}
# PDB code: 4cd8, Affinity Data {'Ki': 0.0013000000000000002, 'resolution': '1.47'}
# PDB code: 4gqq, Affinity Data {'Ki': 0.0013000000000000002, 'resolution': '1.35'}
# PDB code: 4kzb, Affinity Data {'Ki': 0.0013000000000000002, 'resolution': '1.37'}
# PDB code: 4llx, Affinity Data {'Ki': 0.0013, 'resolution': '1.75'}
# PDB code: 4u5u, Affinity Data {'Kd': 0.0013000000000000002, 'resolution': '1.96'}
# PDB code: 4urx, Affinity Data {'Kd': 0.0013000000000000002, 'resolution': '2.49'}
# PDB code: 5aes, Affinity Data {'IC50': 0.0013000000000000002, 'resolution': '2.75'}
# PDB code: 5flt, Affinity Data {'Kd': 0.0012799999999999999, 'resolution': '1.67'}
# PDB code: 5ngz, Affinity Data {'Kd': 0.0013000000000000002, 'resolution': '2.40'}
# PDB code: 5orv, Affinity Data {'Kd': 0.001297, 'resolution': '1.88'}
# PDB code: 6b7b, Affinity Data {'Kd': 0.0012799999999999999, 'resolution': '1.98'}
# PDB code: 6f6s, Affinity Data {'Kd': 0.0013000000000000002, 'resolution': '2.29'}
# PDB code: 6mvu, Affinity Data {'Ki': 0.00129, 'resolution': '1.49'}
# PDB code: 3c2u, Affinity Data {'Ki': 0.00125, 'resolution': '1.30'}
# PDB code: 5aom, Affinity Data {'Kd': 0.0012699999999999999, 'resolution': '1.74'}
# PDB code: 5dv2, Affinity Data {'IC50': 0.00125, 'resolution': '2.07'}
# PDB code: 1ms0, Affinity Data {'Ki': 0.00123, 'resolution': '2.50'}
# PDB code: 2ay4, Affinity Data {'Kd': 0.00124, 'resolution': '2.20'}
# PDB code: 2pri, Affinity Data {'Ki': 0.00123, 'resolution': '2.30'}
# PDB code: 4kc1, Affinity Data {'IC50': 0.00122, 'resolution': '1.50'}
# PDB code: 1eef, Affinity Data {'IC50': 0.0012, 'resolution': '1.80'}
# PDB code: 1h2k, Affinity Data {'Ki': 0.0012, 'resolution': '2.15'}
# PDB code: 1o4k, Affinity Data {'IC50': 0.0012, 'resolution': '1.57'}
# PDB code: 1p6e, Affinity Data {'Ki': 0.00121, 'resolution': '2.30'}
# PDB code: 1zp5, Affinity Data {'IC50': 0.0012, 'resolution': '1.80'}
# PDB code: 2aa9, Affinity Data {'IC50': 0.0012, 'resolution': '1.50'}
# PDB code: 2aay, Affinity Data {'IC50': 0.0012, 'resolution': '1.55'}
# PDB code: 2fkf, Affinity Data {'Kd': 0.0012, 'resolution': '2.00'}
# PDB code: 2fw6, Affinity Data {'Kd': 0.0012, 'resolution': '1.85'}
# PDB code: 2fwp, Affinity Data {'Kd': 0.0012, 'resolution': '1.85'}
# PDB code: 2kfg, Affinity Data {'Kd': 0.0012, 'resolution': 'NMR'}
# PDB code: 3alt, Affinity Data {'Kd': 0.0011899999999999999, 'resolution': '2.50'}
# PDB code: 3iaf, Affinity Data {'Ki': 0.0012, 'resolution': '2.80'}
# PDB code: 3k8c, Affinity Data {'Ki': 0.0012, 'resolution': '2.10'}
# PDB code: 4ai5, Affinity Data {'Kd': 0.0012, 'resolution': '2.22'}
# PDB code: 4ef6, Affinity Data {'Kd': 0.0012, 'resolution': '1.94'}
# PDB code: 4lm3, Affinity Data {'Ki': 0.0012, 'resolution': '1.49'}
# PDB code: 4u4s, Affinity Data {'Kd': 0.0012, 'resolution': '1.90'}
# PDB code: 4x14, Affinity Data {'Kd': 0.0012, 'resolution': '2.30'}
# PDB code: 4y2q, Affinity Data {'Kd': 0.0012, 'resolution': '2.40'}
# PDB code: 4zki, Affinity Data {'Kd': 0.0011949999999999999, 'resolution': '3.40'}
# PDB code: 5c0k, Affinity Data {'IC50': 0.0012, 'resolution': '2.20'}
# PDB code: 5ct2, Affinity Data {'Kd': 0.0012, 'resolution': '2.00'}
# PDB code: 5x4m, Affinity Data {'Kd': 0.0012, 'resolution': '1.65'}
# PDB code: 6fv4, Affinity Data {'Kd': 0.0012, 'resolution': '1.97'}
# PDB code: 1tng, Affinity Data {'Ki': 0.00117, 'resolution': '1.80'}
# PDB code: 3ftv, Affinity Data {'IC50': 0.0011669999999999999, 'resolution': '1.70'}
# PDB code: 4zv2, Affinity Data {'Kd': 0.00117, 'resolution': '1.43'}
# PDB code: 1p6d, Affinity Data {'Ki': 0.00115, 'resolution': '2.00'}
# PDB code: 2vmc, Affinity Data {'Kd': 0.00115, 'resolution': '1.90'}
# PDB code: 4y62, Affinity Data {'IC50': 0.001133, 'resolution': '1.60'}
# PDB code: 1f4e, Affinity Data {'Ki': 0.0011, 'resolution': '1.90'}
# PDB code: 1w1t, Affinity Data {'IC50': 0.0011, 'resolution': '1.90'}
# PDB code: 1ykp, Affinity Data {'Kd': 0.0010999999999999998, 'resolution': '2.41'}
# PDB code: 2br6, Affinity Data {'Ki': 0.0011, 'resolution': '1.70'}
# PDB code: 2kdh, Affinity Data {'Kd': 0.0011, 'resolution': 'NMR'}
# PDB code: 2w8j, Affinity Data {'Kd': 0.0011, 'resolution': '1.50'}
# PDB code: 3g34, Affinity Data {'Ki': 0.0011, 'resolution': '1.31'}
# PDB code: 3imc, Affinity Data {'Kd': 0.0010999999999999998, 'resolution': '1.60'}
# PDB code: 3img, Affinity Data {'Kd': 0.0011, 'resolution': '1.80'}
# PDB code: 4bgy, Affinity Data {'Kd': 0.0011, 'resolution': '2.68'}
# PDB code: 4dst, Affinity Data {'Kd': 0.0011, 'resolution': '2.30'}
# PDB code: 4k3l, Affinity Data {'IC50': 0.0011, 'resolution': '1.50'}
# PDB code: 4mrg, Affinity Data {'Kd': 0.0011, 'resolution': '1.69'}
# PDB code: 4owm, Affinity Data {'Ki': 0.00109, 'resolution': '1.99'}
# PDB code: 5fng, Affinity Data {'Kd': 0.0011049999999999999, 'resolution': '2.05'}
# PDB code: 6r9x, Affinity Data {'Kd': 0.0011, 'resolution': '1.66'}
# PDB code: 2hw2, Affinity Data {'Ki': 0.00107, 'resolution': '1.45'}
# PDB code: 4ceb, Affinity Data {'Kd': 0.00108, 'resolution': '1.75'}
# PDB code: 5flq, Affinity Data {'Kd': 0.00108, 'resolution': '1.70'}
# PDB code: 2rnw, Affinity Data {'Kd': 0.0010509999999999999, 'resolution': 'NMR'}
# PDB code: 3ckb, Affinity Data {'Kd': 0.0010400000000000001, 'resolution': '2.30'}
# PDB code: 3djq, Affinity Data {'Ki': 0.0010464, 'resolution': '1.53'}
# PDB code: 4ibc, Affinity Data {'Kd': 0.001049, 'resolution': '1.75'}
# PDB code: 5aba, Affinity Data {'Kd': 0.00104, 'resolution': '1.62'}
# PDB code: 5aqu, Affinity Data {'Kd': 0.0010400000000000001, 'resolution': '1.92'}
# PDB code: 3ump, Affinity Data {'Ki': 0.001026, 'resolution': '1.85'}
# PDB code: 4a4g, Affinity Data {'Kd': 0.0010249999999999999, 'resolution': 'NMR'}
# PDB code: 4bps, Affinity Data {'Ki': 0.00102, 'resolution': '1.08'}
# PDB code: 1ecq, Affinity Data {'Ki': 0.001, 'resolution': '2.00'}
# PDB code: 1hqg, Affinity Data {'Ki': 0.001, 'resolution': '2.00'}
# PDB code: 1mcz, Affinity Data {'Ki': 0.001, 'resolution': '2.80'}
# PDB code: 1ux7, Affinity Data {'Kd': 0.001, 'resolution': '1.50'}
# PDB code: 1w7h, Affinity Data {'IC50': 0.001, 'resolution': '2.21'}
# PDB code: 1wbg, Affinity Data {'IC50': 0.001, 'resolution': '2.20'}
# PDB code: 1wbo, Affinity Data {'IC50': 0.001, 'resolution': '2.16'}
# PDB code: 1ws4, Affinity Data {'Kd': 0.001, 'resolution': '1.90'}
# PDB code: 1yc5, Affinity Data {'IC50': 0.001, 'resolution': '1.40'}
# PDB code: 1z9h, Affinity Data {'IC50': 0.001, 'resolution': '2.60'}
# PDB code: 1zm7, Affinity Data {'IC50': 0.001, 'resolution': '2.20'}
# PDB code: 2f1b, Affinity Data {'IC50': 0.001, 'resolution': '1.45'}
# PDB code: 2h2e, Affinity Data {'Kd': 0.001, 'resolution': '2.60'}
# PDB code: 2q8h, Affinity Data {'Kd': 0.001, 'resolution': '2.00'}
# PDB code: 2r0y, Affinity Data {'Kd': 0.001, 'resolution': '1.75'}
# PDB code: 2rka, Affinity Data {'Ki': 0.001, 'resolution': '1.95'}
# PDB code: 2v3u, Affinity Data {'Kd': 0.001, 'resolution': '1.74'}
# PDB code: 2vin, Affinity Data {'IC50': 0.001, 'resolution': '1.90'}
# PDB code: 2vtm, Affinity Data {'IC50': 0.001, 'resolution': '2.25'}
# PDB code: 2wa3, Affinity Data {'IC50': 0.001, 'resolution': '2.50'}
# PDB code: 2xgm, Affinity Data {'Kd': 0.001, 'resolution': '2.55'}
# PDB code: 2xgo, Affinity Data {'Kd': 0.001, 'resolution': '2.60'}
# ...
# PDB code: 6dyy, Affinity Data {'Kd': 2.8000000000000003e-11, 'resolution': '1.61'}
# PDB code: 6oxw, Affinity Data {'Ki': 2.8000000000000003e-11, 'resolution': '1.98'}
# PDB code: 1oxg, Affinity Data {'Ki': 2.7e-11, 'resolution': '2.20'}
# PDB code: 1qbr, Affinity Data {'Ki': 2.7e-11, 'resolution': '1.80'}
# PDB code: 2qi6, Affinity Data {'Ki': 2.7e-11, 'resolution': '1.85'}
# PDB code: 4xtx, Affinity Data {'Kd': 2.7e-11, 'resolution': '2.30'}
# PDB code: 6dh1, Affinity Data {'Ki': 2.6100000000000002e-11, 'resolution': '1.97'}
# PDB code: 3djk, Affinity Data {'Ki': 2.6e-11, 'resolution': '1.00'}
# PDB code: 3ekt, Affinity Data {'Kd': 2.6e-11, 'resolution': '1.97'}
# PDB code: 3lzv, Affinity Data {'Kd': 2.6e-11, 'resolution': '2.15'}
# PDB code: 5dro, Affinity Data {'Ki': 2.6e-11, 'resolution': '2.01'}
# PDB code: 6dh0, Affinity Data {'Ki': 2.56e-11, 'resolution': '1.90'}
# PDB code: 6dyv, Affinity Data {'Kd': 2.6e-11, 'resolution': '1.62'}
# PDB code: 2j4a, Affinity Data {'IC50': 2.5000000000000004e-11, 'resolution': '2.20'}
# PDB code: 2zx6, Affinity Data {'Ki': 2.5100000000000003e-11, 'resolution': '2.42'}
# PDB code: 4uxl, Affinity Data {'Ki': 2.5000000000000004e-11, 'resolution': '2.40'}
# PDB code: 5uov, Affinity Data {'Ki': 2.5000000000000004e-11, 'resolution': '1.33'}
# PDB code: 1qbt, Affinity Data {'Ki': 2.4e-11, 'resolution': '2.10'}
# PDB code: 2xei, Affinity Data {'Ki': 2.4e-11, 'resolution': '1.69'}
# PDB code: 4lch, Affinity Data {'Ki': 2.4e-11, 'resolution': '1.60'}
# PDB code: 1b8o, Affinity Data {'Ki': 2.2999999999999998e-11, 'resolution': '1.50'}
# PDB code: 6eqw, Affinity Data {'Ki': 2.2399999999999998e-11, 'resolution': '1.99'}
# PDB code: 1dif, Affinity Data {'Ki': 2.1999999999999998e-11, 'resolution': '1.70'}
# PDB code: 5fkj, Affinity Data {'Ki': 2.1999999999999998e-11, 'resolution': '3.13'}
# PDB code: 1xon, Affinity Data {'IC50': 2.1000000000000002e-11, 'resolution': '1.72'}
# PDB code: 3cs7, Affinity Data {'Ki': 2.1e-11, 'resolution': '2.20'}
# PDB code: 2pk5, Affinity Data {'Kd': 2e-11, 'resolution': '1.90'}
# PDB code: 2wva, Affinity Data {'Kd': 2e-11, 'resolution': '2.20'}
# PDB code: 2xeg, Affinity Data {'Ki': 2.0000000000000002e-11, 'resolution': '1.59'}
# PDB code: 3myg, Affinity Data {'Kd': 2.0000000000000002e-11, 'resolution': '2.40'}
# PDB code: 3o9a, Affinity Data {'Ki': 2e-11, 'resolution': '1.90'}
# PDB code: 4agc, Affinity Data {'Ki': 2.0000000000000002e-11, 'resolution': '2.00'}
# PDB code: 4an0, Affinity Data {'Ki': 2.0000000000000002e-11, 'resolution': '2.20'}
# PDB code: 5nee, Affinity Data {'Ki': 2.0000000000000002e-11, 'resolution': '1.70'}
# PDB code: 5wb6, Affinity Data {'Ki': 2.0000000000000002e-11, 'resolution': '2.35'}
# PDB code: 6oxv, Affinity Data {'Ki': 2.0000000000000002e-11, 'resolution': '1.99'}
# PDB code: 5alb, Affinity Data {'Kd': 1.9600000000000002e-11, 'resolution': '2.16'}
# PDB code: 2o4p, Affinity Data {'Kd': 1.9e-11, 'resolution': '1.80'}
# PDB code: 2wzy, Affinity Data {'Kd': 1.9e-11, 'resolution': '2.51'}
# PDB code: 3o9d, Affinity Data {'Ki': 1.9e-11, 'resolution': '1.85'}
# PDB code: 5tys, Affinity Data {'IC50': 1.9000000000000002e-11, 'resolution': '2.01'}
# PDB code: 6dif, Affinity Data {'Ki': 1.9000000000000002e-11, 'resolution': '1.20'}
# PDB code: 7std, Affinity Data {'Ki': 1.9e-11, 'resolution': '1.80'}
# PDB code: 4yho, Affinity Data {'Kd': 1.8e-11, 'resolution': '1.82'}
# PDB code: 6o0k, Affinity Data {'Ki': 1.8e-11, 'resolution': '1.62'}
# PDB code: 4gid, Affinity Data {'Ki': 1.7000000000000003e-11, 'resolution': '2.00'}
# PDB code: 4omc, Affinity Data {'Ki': 1.6699999999999998e-11, 'resolution': '2.30'}
# PDB code: 1c4v, Affinity Data {'Ki': 1.6000000000000003e-11, 'resolution': '2.10'}
# PDB code: 2ajd, Affinity Data {'Ki': 1.6e-11, 'resolution': '2.56'}
# PDB code: 3gi4, Affinity Data {'Ki': 1.6e-11, 'resolution': '1.85'}
# PDB code: 4hla, Affinity Data {'Ki': 1.6e-11, 'resolution': '1.95'}
# PDB code: 5c1m, Affinity Data {'Ki': 1.6e-11, 'resolution': '2.10'}
# PDB code: 6h5w, Affinity Data {'Ki': 1.6000000000000003e-11, 'resolution': '1.37'}
# PDB code: 6u7o, Affinity Data {'Ki': 1.5499999999999998e-11, 'resolution': '1.33'}
# PDB code: 1ebg, Affinity Data {'Ki': 1.5e-11, 'resolution': '2.10'}
# PDB code: 1els, Affinity Data {'Ki': 1.5e-11, 'resolution': '2.40'}
# PDB code: 1hxw, Affinity Data {'Ki': 1.5e-11, 'resolution': '1.80'}
# PDB code: 3o99, Affinity Data {'Ki': 1.5e-11, 'resolution': '1.95'}
# PDB code: 4amy, Affinity Data {'Ki': 1.5e-11, 'resolution': '2.00'}
# PDB code: 5wlo, Affinity Data {'Ki': 1.5e-11, 'resolution': '1.27'}
# PDB code: 6h5x, Affinity Data {'Ki': 1.5e-11, 'resolution': '1.80'}
# PDB code: 2qi5, Affinity Data {'Ki': 1.4000000000000002e-11, 'resolution': '1.85'}
# PDB code: 3ggv, Affinity Data {'Ki': 1.4000000000000002e-11, 'resolution': '3.09'}
# PDB code: 3i7e, Affinity Data {'Ki': 1.4e-11, 'resolution': '1.70'}
# PDB code: 5ult, Affinity Data {'Ki': 1.4000000000000002e-11, 'resolution': '1.53'}
# PDB code: 2pk6, Affinity Data {'Kd': 1.3e-11, 'resolution': '1.45'}
# PDB code: 6dh2, Affinity Data {'Ki': 1.28e-11, 'resolution': '1.98'}
# PDB code: 4i8w, Affinity Data {'Ki': 1.2699999999999999e-11, 'resolution': '1.96'}
# PDB code: 1hvi, Affinity Data {'Ki': 1.2e-11, 'resolution': '1.80'}
# PDB code: 3utu, Affinity Data {'Ki': 1.2e-11, 'resolution': '1.55'}
# PDB code: 5drq, Affinity Data {'Ki': 1.2e-11, 'resolution': '1.63'}
# PDB code: 6cdl, Affinity Data {'Ki': 1.2e-11, 'resolution': '1.25'}
# PDB code: 1hvk, Affinity Data {'Ki': 1.0999999999999999e-11, 'resolution': '1.80'}
# PDB code: 1m7y, Affinity Data {'Kd': 1.1e-11, 'resolution': '1.60'}
# PDB code: 1n9m, Affinity Data {'Kd': 1.0999999999999999e-11, 'resolution': '1.60'}
# PDB code: 2jb6, Affinity Data {'Kd': 1.0999999999999999e-11, 'resolution': '2.85'}
# PDB code: 3lzs, Affinity Data {'Kd': 1.0900000000000001e-11, 'resolution': '1.95'}
# PDB code: 5nn0, Affinity Data {'Kd': 1.0999999999999999e-11, 'resolution': '2.10'}
# PDB code: 1dis, Affinity Data {'Ki': 1.0000000000000001e-11, 'resolution': 'NMR'}
# PDB code: 1swp, Affinity Data {'Kd': 1e-11, 'resolution': '2.00'}
# PDB code: 4ase, Affinity Data {'Ki': 1.0000000000000001e-11, 'resolution': '1.83'}
# PDB code: 4kb9, Affinity Data {'Ki': 1.0000000000000001e-11, 'resolution': '1.29'}
# PDB code: 4man, Affinity Data {'Ki': 1.0000000000000001e-11, 'resolution': '2.07'}
# PDB code: 4qvx, Affinity Data {'Ki': 1.0000000000000001e-11, 'resolution': '2.10'}
# PDB code: 5bs4, Affinity Data {'Kd': 9.900000000000001e-12, 'resolution': '1.29'}
# PDB code: 5bve, Affinity Data {'IC50': 1.0000000000000001e-11, 'resolution': '2.00'}
# PDB code: 5ew9, Affinity Data {'Ki': 1.0000000000000001e-11, 'resolution': '2.18'}
# PDB code: 6oxp, Affinity Data {'Ki': 1.0000000000000001e-11, 'resolution': '1.97'}
# PDB code: 5j5x, Affinity Data {'Kd': 9.500000000000001e-12, 'resolution': '2.60'}
# PDB code: 1dqx, Affinity Data {'Ki': 9e-12, 'resolution': '2.40'}
# PDB code: 1q84, Affinity Data {'Ki': 8.900000000000001e-12, 'resolution': '2.45'}
# PDB code: 4i8z, Affinity Data {'Ki': 8.9e-12, 'resolution': '1.75'}
# PDB code: 5dgw, Affinity Data {'Ki': 9e-12, 'resolution': '1.62'}
# PDB code: 1eix, Affinity Data {'Ki': 8.800000000000001e-12, 'resolution': '2.50'}
# PDB code: 1jjk, Affinity Data {'Ki': 8.800000000000001e-12, 'resolution': '3.00'}
# PDB code: 1lor, Affinity Data {'Ki': 8.800000000000001e-12, 'resolution': '1.60'}
# PDB code: 1x1z, Affinity Data {'Ki': 8.800000000000001e-12, 'resolution': '1.45'}
# PDB code: 3k8o, Affinity Data {'Kd': 8.6e-12, 'resolution': '2.40'}
# PDB code: 4x3r, Affinity Data {'Ki': 8.6e-12, 'resolution': '1.86'}
# PDB code: 5c2h, Affinity Data {'Ki': 8.2e-12, 'resolution': '2.09'}
# PDB code: 1d4y, Affinity Data {'Ki': 8.000000000000001e-12, 'resolution': '1.97'}
# PDB code: 3gwt, Affinity Data {'IC50': 7.94e-12, 'resolution': '1.75'}
# PDB code: 3std, Affinity Data {'Ki': 7.7e-12, 'resolution': '1.65'}
# PDB code: 5llg, Affinity Data {'Kd': 7.400000000000002e-12, 'resolution': '1.12'}
# PDB code: 1mq6, Affinity Data {'Ki': 7e-12, 'resolution': '2.10'}
# PDB code: 3m9f, Affinity Data {'IC50': 7.000000000000001e-12, 'resolution': '1.80'}
# PDB code: 4q1x, Affinity Data {'Ki': 7e-12, 'resolution': '1.90'}
# PDB code: 2i4v, Affinity Data {'Ki': 6.2999999999999994e-12, 'resolution': '1.50'}
# PDB code: 5h8e, Affinity Data {'Kd': 6.33e-12, 'resolution': '2.15'}
# PDB code: 1sme, Affinity Data {'Ki': 6e-12, 'resolution': '2.70'}
# PDB code: 3gi5, Affinity Data {'Ki': 6e-12, 'resolution': '1.80'}
# PDB code: 3gi6, Affinity Data {'Ki': 6e-12, 'resolution': '1.84'}
# PDB code: 5dwr, Affinity Data {'Ki': 6e-12, 'resolution': '2.00'}
# PDB code: 5qim, Affinity Data {'IC50': 6e-12, 'resolution': '1.75'}
# PDB code: 3ok9, Affinity Data {'Ki': 5.9e-12, 'resolution': '1.27'}
# PDB code: 4u8w, Affinity Data {'Ki': 5.7999999999999995e-12, 'resolution': '1.30'}
# PDB code: 1hpx, Affinity Data {'Ki': 5.4999999999999996e-12, 'resolution': '2.00'}
# PDB code: 4ryd, Affinity Data {'Ki': 5.4999999999999996e-12, 'resolution': '2.15'}
# PDB code: 3k8q, Affinity Data {'Kd': 5.2000000000000005e-12, 'resolution': '2.50'}
# PDB code: 6mqe, Affinity Data {'Kd': 5.1000000000000005e-12, 'resolution': '2.46'}
# PDB code: 1mau, Affinity Data {'Kd': 5e-12, 'resolution': '2.15'}
# PDB code: 1pro, Affinity Data {'Ki': 5e-12, 'resolution': '1.80'}
# PDB code: 2q5k, Affinity Data {'Ki': 5e-12, 'resolution': '1.95'}
# PDB code: 2xpk, Affinity Data {'Ki': 5.0000000000000005e-12, 'resolution': '2.40'}
# PDB code: 3o9e, Affinity Data {'Ki': 5e-12, 'resolution': '1.50'}
# PDB code: 3st5, Affinity Data {'Ki': 5e-12, 'resolution': '1.45'}
# PDB code: 4f2w, Affinity Data {'Ki': 5e-12, 'resolution': '2.00'}
# PDB code: 6dgx, Affinity Data {'Ki': 5e-12, 'resolution': '2.00'}
# PDB code: 6dgy, Affinity Data {'Ki': 5e-12, 'resolution': '1.95'}
# PDB code: 6dgz, Affinity Data {'Ki': 5e-12, 'resolution': '1.99'}
# PDB code: 6dh3, Affinity Data {'Ki': 5e-12, 'resolution': '1.91'}
# PDB code: 6dh4, Affinity Data {'Ki': 5e-12, 'resolution': '1.94'}
# PDB code: 6dh5, Affinity Data {'Ki': 5e-12, 'resolution': '2.01'}
# PDB code: 6oos, Affinity Data {'Ki': 5.0000000000000005e-12, 'resolution': '1.90'}
# PDB code: 6oot, Affinity Data {'Ki': 5.0000000000000005e-12, 'resolution': '1.82'}
# PDB code: 6oou, Affinity Data {'Ki': 5.0000000000000005e-12, 'resolution': '2.13'}
# PDB code: 6oxq, Affinity Data {'Ki': 5.0000000000000005e-12, 'resolution': '1.89'}
# PDB code: 5h8b, Affinity Data {'Kd': 4.91e-12, 'resolution': '2.55'}
# PDB code: 1nl6, Affinity Data {'Ki': 4.8e-12, 'resolution': '2.80'}
# PDB code: 4gbd, Affinity Data {'Ki': 4.8e-12, 'resolution': '1.98'}
# PDB code: 2x00, Affinity Data {'Kd': 4.7e-12, 'resolution': '2.40'}
# PDB code: 2j62, Affinity Data {'Ki': 4.6e-12, 'resolution': '2.26'}
# PDB code: 2hb3, Affinity Data {'Ki': 4.5e-12, 'resolution': '1.35'}
# PDB code: 5dgu, Affinity Data {'Ki': 4.5e-12, 'resolution': '1.22'}
# PDB code: 1hvj, Affinity Data {'Ki': 4e-12, 'resolution': '2.00'}
# PDB code: 2i0a, Affinity Data {'Ki': 4e-12, 'resolution': '1.80'}
# PDB code: 3wv1, Affinity Data {'IC50': 3.9e-12, 'resolution': '1.98'}
# PDB code: 1lyb, Affinity Data {'Ki': 3.8e-12, 'resolution': '2.50'}
# PDB code: 4ocx, Affinity Data {'Kd': 3.6e-12, 'resolution': '2.39'}
# PDB code: 5drr, Affinity Data {'Ki': 3.5e-12, 'resolution': '1.59'}
# PDB code: 4djo, Affinity Data {'Ki': 3e-12, 'resolution': '1.78'}
# PDB code: 4djr, Affinity Data {'Ki': 3e-12, 'resolution': '1.55'}
# PDB code: 4k1b, Affinity Data {'Ki': 3e-12, 'resolution': '2.08'}
# PDB code: 5hln, Affinity Data {'IC50': 3e-12, 'resolution': '3.10'}
# PDB code: 5izj, Affinity Data {'Kd': 3e-12, 'resolution': '1.85'}
# PDB code: 5qil, Affinity Data {'IC50': 3e-12, 'resolution': '1.98'}
# PDB code: 6cpa, Affinity Data {'Ki': 3e-12, 'resolution': '2.00'}
# PDB code: 3qaa, Affinity Data {'Ki': 2.8999999999999998e-12, 'resolution': '1.40'}
# PDB code: 2i4u, Affinity Data {'Ki': 2.7000000000000002e-12, 'resolution': '1.50'}
# PDB code: 4ll3, Affinity Data {'Kd': 2.7000000000000002e-12, 'resolution': '1.95'}
# PDB code: 4wkb, Affinity Data {'Ki': 2.7000000000000002e-12, 'resolution': '1.37'}
# PDB code: 1akv, Affinity Data {'Kd': 2.6000000000000002e-12, 'resolution': '2.00'}
# PDB code: 2i4w, Affinity Data {'Ki': 2.6000000000000002e-12, 'resolution': '1.55'}
# PDB code: 5ehn, Affinity Data {'Ki': 2.3e-12, 'resolution': '2.60'}
# PDB code: 2i4d, Affinity Data {'Ki': 2.1e-12, 'resolution': '1.50'}
# PDB code: 4jn2, Affinity Data {'Kd': 2.1e-12, 'resolution': '1.71'}
# PDB code: 6u7p, Affinity Data {'Ki': 2.1e-12, 'resolution': '1.13'}
# PDB code: 1y6q, Affinity Data {'Ki': 2e-12, 'resolution': '2.20'}
# PDB code: 2fv5, Affinity Data {'Kd': 2e-12, 'resolution': '2.10'}
# PDB code: 4q1w, Affinity Data {'Ki': 2e-12, 'resolution': '1.85'}
# PDB code: 4wr7, Affinity Data {'Kd': 2.0000000000000004e-12, 'resolution': '1.50'}
# PDB code: 5mw4, Affinity Data {'Ki': 2.0000000000000004e-12, 'resolution': '2.19'}
# PDB code: 6cdj, Affinity Data {'Ki': 2.0000000000000004e-12, 'resolution': '1.13'}
# PDB code: 2i4x, Affinity Data {'Ki': 1.9e-12, 'resolution': '1.55'}
# PDB code: 4dfg, Affinity Data {'Ki': 1.8e-12, 'resolution': '1.23'}
# PDB code: 1duv, Affinity Data {'Kd': 1.6e-12, 'resolution': '1.70'}
# PDB code: 3o9i, Affinity Data {'Ki': 1.5e-12, 'resolution': '1.45'}
# PDB code: 4f3c, Affinity Data {'Ki': 1.5e-12, 'resolution': '1.93'}
# PDB code: 5bry, Affinity Data {'Ki': 1.5e-12, 'resolution': '1.34'}
# PDB code: 1sl3, Affinity Data {'Ki': 1.3999999999999999e-12, 'resolution': '1.81'}
# PDB code: 1mui, Affinity Data {'Ki': 1.3000000000000001e-12, 'resolution': '2.80'}
# PDB code: 1ctu, Affinity Data {'Ki': 1.2e-12, 'resolution': '2.30'}
# PDB code: 6e9a, Affinity Data {'Ki': 1.2e-12, 'resolution': '1.22'}
# PDB code: 1agm, Affinity Data {'Ki': 1e-12, 'resolution': '2.30'}
# PDB code: 1gah, Affinity Data {'Ki': 1e-12, 'resolution': '2.00'}
# PDB code: 1lf9, Affinity Data {'Ki': 1e-12, 'resolution': '2.20'}
# PDB code: 1swk, Affinity Data {'Kd': 1e-12, 'resolution': '2.00'}
# PDB code: 1swn, Affinity Data {'Kd': 1e-12, 'resolution': '2.20'}
# PDB code: 4n70, Affinity Data {'Ki': 1e-12, 'resolution': '2.10'}
# PDB code: 6b5m, Affinity Data {'Kd': 1.0000000000000002e-12, 'resolution': '1.79'}
# PDB code: 3o9c, Affinity Data {'Ki': 9e-13, 'resolution': '1.85'}
# PDB code: 2i0d, Affinity Data {'Ki': 8e-13, 'resolution': '1.95'}
# PDB code: 3o9h, Affinity Data {'Ki': 8e-13, 'resolution': '1.70'}
# PDB code: 1ndj, Affinity Data {'Kd': 6.899999999999999e-13, 'resolution': '1.81'}
# PDB code: 3o9b, Affinity Data {'Ki': 5e-13, 'resolution': '1.50'}
# PDB code: 3o9g, Affinity Data {'Ki': 5e-13, 'resolution': '1.65'}
# PDB code: 6c8x, Affinity Data {'Ki': 5e-13, 'resolution': '1.61'}
# PDB code: 2zx5, Affinity Data {'Kd': 4.689999999999999e-13, 'resolution': '2.65'}
# PDB code: 1q83, Affinity Data {'Ki': 4.1e-13, 'resolution': '2.65'}
# PDB code: 2xup, Affinity Data {'Kd': 4.0999999999999997e-13, 'resolution': '2.70'}
# PDB code: 4wkc, Affinity Data {'Ki': 2.1e-13, 'resolution': '1.64'}
# PDB code: 3o9f, Affinity Data {'Ki': 2e-13, 'resolution': '1.70'}
# PDB code: 1rbo, Affinity Data {'Kd': 1.9e-13, 'resolution': '2.30'}
# PDB code: 1a4m, Affinity Data {'Ki': 1e-13, 'resolution': '1.95'}
# PDB code: 2ada, Affinity Data {'Ki': 1e-13, 'resolution': '2.40'}
# PDB code: 2c1q, Affinity Data {'Kd': 1e-13, 'resolution': '2.10'}
# PDB code: 2f01, Affinity Data {'Kd': 1e-13, 'resolution': '0.85'}
# PDB code: 2gh7, Affinity Data {'Kd': 1e-13, 'resolution': '1.00'}
# PDB code: 2uyw, Affinity Data {'Kd': 1e-13, 'resolution': '1.70'}
# PDB code: 1stp, Affinity Data {'Kd': 4.0000000000000006e-14, 'resolution': '2.60'}
# PDB code: 1eol, Affinity Data {'Ki': 3.8e-14, 'resolution': '2.10'}
# PDB code: 1eoj, Affinity Data {'Ki': 1.7e-14, 'resolution': '2.10'}
# PDB code: 1amn, Affinity Data {'Ki': 1.5000000000000002e-14, 'resolution': '2.80'}
# PDB code: 7cpa, Affinity Data {'Ki': 1.1e-14, 'resolution': '2.00'}
# PDB code: 2xuf, Affinity Data {'Kd': 4.0999999999999996e-15, 'resolution': '2.55'}
# PDB code: 1avd, Affinity Data {'Kd': 1e-15, 'resolution': '2.70'}
# PDB code: 2xui, Affinity Data {'Kd': 1e-15, 'resolution': '2.60'}
# PDB code: 2avi, Affinity Data {'Kd': 6e-16, 'resolution': '3.00'}

# %%
import pandas as pd
affinities = []

for pdb_code, value in results_general.items():

    if 'Ki' in value.keys(): affinities.append(value['Ki'])
    if 'Kd' in value.keys(): affinities.append(value['Kd'])
    if 'IC50' in value.keys(): affinities.append(value['IC50'])


affinities = sorted(affinities)
np_affinities = np.array(affinities)
neglog_affinities = (-1)* np.log(np_affinities)

stack = np.vstack((np.array(affinities), np_affinities, neglog_affinities))
df = pd.DataFrame(stack).transpose()
df
# Out:
#                   0             1          2
# 0      6.000000e-16  6.000000e-16  35.049602
# 1      1.000000e-15  1.000000e-15  34.538776
# 2      1.000000e-15  1.000000e-15  34.538776
# 3      4.100000e-15  4.100000e-15  33.127789
# 4      1.100000e-14  1.100000e-14  32.140881
# ...             ...           ...        ...
# 19438  2.500000e-01  2.500000e-01   1.386294
# 19439  3.200000e-01  3.200000e-01   1.139434
# 19440  3.200000e-01  3.200000e-01   1.139434
# 19441  3.550000e-01  3.550000e-01   1.035637
# 19442  4.000000e-01  4.000000e-01   0.916291
#
# [19443 rows x 3 columns]

# %%
df.describe()
# Out:
#                   0             1             2
# count  1.944300e+04  1.944300e+04  19443.000000
# mean   4.340430e-04  4.340430e-04     14.637318
# std    6.671503e-03  6.671503e-03      4.274482
# min    6.000000e-16  6.000000e-16      0.916291
# 25%    2.000000e-08  2.000000e-08     11.596307
# 50%    3.870000e-07  3.870000e-07     14.764841
# 75%    9.200000e-06  9.200000e-06     17.727534
# max    4.000000e-01  4.000000e-01     35.049602

# %%
# Set figure size with double width
plt.figure(figsize=(16, 6))  # default is usually (6, 4)

# Create the histogram with log scale for y-axis
n, bins, patches = plt.hist(affinities, bins=50, edgecolor='black', alpha=0.7, log=True)

# Annotate bars with their counts
for i in range(50):
    if n[i] > 0:  # To avoid placing text for bins with no counts on a log scale
        plt.text(bins[i]+(bins[i+1]-bins[i])/2, n[i]*1.1, str(int(n[i])),
                 ha='center', va='center', fontweight='bold', fontsize=8)

# Setting the y-axis to logarithmic
plt.yscale('log')

plt.xlabel('Value')
plt.ylabel('Frequency')
plt.title('Histogram with Counts on Log Scale')
plt.show()

# %%
# Set figure size with double width
plt.figure(figsize=(16, 6))  # default is usually (6, 4)

# Create the histogram with log scale for y-axis
n, bins, patches = plt.hist(neglog_affinities, bins=50, edgecolor='black', alpha=0.7, log=True)

# Annotate bars with their counts
for i in range(50):
    if n[i] > 0:  # To avoid placing text for bins with no counts on a log scale
        plt.text(bins[i]+(bins[i+1]-bins[i])/2, n[i]*1.1, str(int(n[i])),
                 ha='center', va='center', fontweight='bold', fontsize=8)

# Setting the y-axis to logarithmic
plt.yscale('log')

plt.xlabel('Value')
plt.ylabel('Frequency')
plt.title('Histogram with Counts on Log Scale and Negative Log Affinities')
plt.show()

# %%
# Set figure size with double width
plt.figure(figsize=(16, 6))  # default is usually (6, 4)

# Create the histogram with log scale for y-axis
n, bins, patches = plt.hist(neglog_affinities, bins=50, edgecolor='black', alpha=0.7, log=True)

# Annotate bars with their counts
for i in range(50):
    if n[i] > 0:  # To avoid placing text for bins with no counts on a log scale
        plt.text(bins[i]+(bins[i+1]-bins[i])/2, n[i]*1.01, str(int(n[i])),
                 ha='center', va='center', fontweight='bold', fontsize=8)

# Setting the y-axis to logarithmic
plt.yscale('linear')

plt.xlabel('Value')
plt.ylabel('Frequency')
plt.title('Histogram with Counts on Linear Scale and Negative Log Affinities')
plt.show()

# %%
# Remove tails with extreme values: 

# min in neglog could be 2 -- Extremely low binding (10 datapoints would be clipped)
# max in neglog could be 30 -- Extremely strong affinity (9 datapoints would be clipped)

# %%
neglog_affinities_clip = np.clip(neglog_affinities, 2, 30)

# %%
# Set figure size with double width
plt.figure(figsize=(16, 6))  # default is usually (6, 4)

# Create the histogram with log scale for y-axis
n, bins, patches = plt.hist(neglog_affinities_clip, bins=50, edgecolor='black', alpha=0.7, log=True)

# Annotate bars with their counts
for i in range(50):
    if n[i] > 0:  # To avoid placing text for bins with no counts on a log scale
        plt.text(bins[i]+(bins[i+1]-bins[i])/2, n[i]*1.01, str(int(n[i])),
                 ha='center', va='center', fontweight='bold', fontsize=8)

# Setting the y-axis to logarithmic
plt.yscale('linear')

plt.xlabel('Value')
plt.ylabel('Frequency')
plt.title('Histogram with Counts on Linear Scale and Negative Log Affinities')
plt.show()

# %%
# Min-Max Scale

neglog_affinities_clip_scaled = (neglog_affinities_clip - np.min(neglog_affinities_clip)) / (np.max(neglog_affinities_clip) - np.min(neglog_affinities_clip))

# %%
# Set figure size with double width
plt.figure(figsize=(16, 6))  # default is usually (6, 4)

# Create the histogram with log scale for y-axis
n, bins, patches = plt.hist(neglog_affinities_clip_scaled, bins=50, edgecolor='black', alpha=0.7, log=True)

# Annotate bars with their counts
for i in range(50):
    if n[i] > 0:  # To avoid placing text for bins with no counts on a log scale
        plt.text(bins[i]+(bins[i+1]-bins[i])/2, n[i]*1.01, str(int(n[i])),
                 ha='center', va='center', fontweight='bold', fontsize=8)

# Setting the y-axis to logarithmic
plt.yscale('linear')

plt.xlabel('Value')
plt.ylabel('Frequency')
plt.title('Histogram with Counts on Linear Scale and Negative Log Affinities')
plt.show()

# %% [markdown]
# ### Test how the transformation needs to be done in Dataset.py

# %%
collected_transformed = []

import torch

min = 2
max = 30

for aff in affinities:

    aff = torch.tensor(aff)
    log = torch.clamp(-torch.log(aff), min, max)
    scaled = (log - min) / (max - min)

    collected_transformed.append(scaled)

# %%
# Set figure size with double width
plt.figure(figsize=(16, 6))  # default is usually (6, 4)

# Create the histogram with log scale for y-axis
n, bins, patches = plt.hist(collected_transformed, bins=50, edgecolor='black', alpha=0.7, log=True)

# Annotate bars with their counts
for i in range(50):
    if n[i] > 0:  # To avoid placing text for bins with no counts on a log scale
        plt.text(bins[i]+(bins[i+1]-bins[i])/2, n[i]*1.01, str(int(n[i])),
                 ha='center', va='center', fontweight='bold', fontsize=8)

# Setting the y-axis to logarithmic
plt.yscale('linear')

plt.xlabel('Value')
plt.ylabel('Frequency')
plt.title('Histogram with Counts on Linear Scale and Negative Log Affinities')
plt.show()
